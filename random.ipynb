# %%
import random
s = '0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxy'
res = []
for i in range(len(s)):
    res.append(s[i])

# %%
random.shuffle(res)

# %%
s=''.join(res)

# %%
s = '0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxy'
s1 = list(s)

# %%
random.randint(0, 55)
# Out:
# 23

# %%
s1.pop(10)
# Out:
# 'A'

# %% [markdown]
# n = input()
# n = int(n)
# a = list(map(int, input().split()))
# operations = 0
#
# for i in range(1, n):
#     if a[i] < a[i-1]:
#         operations += a[i-1] - a[i]
#         a[i] = a[i-1]
#
# print(operations)
