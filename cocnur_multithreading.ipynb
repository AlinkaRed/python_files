# %% [markdown]
# https://all-python.ru/osnovy/threading.html
# https://habr.com/ru/articles/804799/

# %%
import time
from time import sleep
from threading import Thread, Lock

# %%
def timer(func):
    def inner(*args, **kwargs):
        start = time.time()
        res = func(*args, **kwargs)
        elapsed = time.time() - start
        print(f'Time: {elapsed:.5f} sec ({func.__name__})')
        return res
    return inner

# %% [markdown]
# ### Задача 1

# %%
# Функция, которая будет применена к каждому элементу
def square(n):
    return n * n

# Входной список значений
vals = [1, 2, 3, 4, 5]

# %%
@timer
def sync1(values: list):
    # Список для хранения результатов
    results = []

    def worker(value):
        result = square(value)
        results.append(result)
    
    for val in values:
        worker(val)
    
    print(results)

sync1(vals)
# Out:
# [1, 4, 9, 16, 25]
# Time: 0.00000 sec (sync1)

# %%
@timer
def threaded1(values: list):
    # Список для хранения результатов
    results = []
    lock = Lock()  # Создаем объект блокировки
    
    # Функция для выполнения в потоке
    def worker(value):
        result = square(value)
        with lock:  # Блокируем доступ к общему ресурсу results
            results.append(result)
    
    # Создание и запуск потоков для вызова функции square
    threads = []
    for value in values:
        thread = Thread(target=worker, args=(value,))
        thread.start()
        threads.append(thread)
    
    # Ожидание завершения всех потоков
    for thread in threads:
        thread.join()
    
    print(results)

threaded1(vals)
# Out:
# [1, 4, 9, 16, 25]
# Time: 0.00147 sec (threaded1)

# %% [markdown]
# ### Вывод: CPU-bound операции в потоках выполняются чуть медленнее. чем в синхр.варианте

# %% [markdown]
# ## Lock

# %% [markdown]
# ### Race condition (гонка состояний) - ошибка при доступе к общим ресурсам

# %%
counter = 0

def increase(by):
    global counter

    local_counter = counter
    local_counter += by

    time.sleep(0.1)

    counter = local_counter
    print(f'{counter=}\n')


t1 = Thread(target=increase, args=(10,))
t2 = Thread(target=increase, args=(20,))

t1.start()
t2.start()

t1.join()
t2.join()
# Out:
# counter=10
# counter=20

# %%
counter = 0

def increase(by, lock: Lock):
    global counter

    lock.acquire()

    local_counter = counter
    local_counter += by

    sleep(0.1)

    counter = local_counter
    print(f'{counter=}')

    lock.release()

lock = Lock()

t1 = Thread(target=increase, args=(10, lock,))
t2 = Thread(target=increase, args=(20, lock,))

t1.start()
t2.start()

t1.join()
t2.join()
# Out:
# counter=10
# counter=30

# %% [markdown]
# #### Состояние гонки может приводить к различным проблемам:
#
# * Утечки памяти.
# * Потеря данных.
# * Уязвимости в безопасности программы.
# * Получение ошибочных результатов.
# * Взаимные блокировки потоков.

# %% [markdown]
# ### DeadLock

# %%
a = 5
b = 10

a_lock = Lock()
b_lock = Lock()

def function_a():
    global a
    global b

    a_lock.acquire()
    print('Функция a, a_lock = заблокирован')
    sleep(1)
    b_lock.acquire()
    print('Функция a, b_lock = заблокирован')

    sleep(1)

    a_lock.release()
    print('Функция a, a_lock = разблокирован')
    b_lock.release()
    print('Функция a, b_lock = разблокирован')

def function_b():
    global a
    global b

    b_lock.acquire()
    print('Функция b, b_lock = заблокирован')
    a_lock.acquire()
    print('Функция b, a_lock = заблокирован')

    sleep(1)

    b_lock.release()
    print('Функция b, b_lock = разблокирован')
    a_lock.release()
    print('Функция b, a_lock = разблокирован')

t1 = Thread(target=function_a)
t2 = Thread(target=function_b)

t1.start()
t2.start()

t1.join()
t2.join()

print('Готово')
# Out:
# Функция a, a_lock = заблокирован
# Функция b, b_lock = заблокирован

# %% [markdown]
# ### Решение Deadlock
#
# 1. lock как контекстный менеджер
# ```
# lock = threading.Lock()
# with lock:
#     # операторы
#     pass
# ```
#
# 2. Использование try-finally
# ```
# lock = threading.Lock()
# lock.acquire()
# try:
#     # операторы
#     pass
# finally:
#     lock.release()
# ```
#
# 3. Semathore

# %% [markdown]
# #### Semathore

# %%
import datetime
from threading import Semaphore

s = Semaphore(3)


def semaphore_func(value: int):
    s.acquire()
    now = datetime.datetime.now().strftime('%H:%M:%S')
    print(f'{now=}, {value=}')
    sleep(2)
    s.release()


threads = [Thread(target=semaphore_func, args=(i,)) for i in range(7)]

for t in threads:
    t.start()

for t in threads:
    t.join()
# Out:
# now='11:24:53', value=0
# now='11:24:53', value=1
# now='11:24:53', value=2
# now='11:24:55', value=3
# now='11:24:55', value=4
# now='11:24:55', value=5
# now='11:24:57', value=6

# %% [markdown]
# ### Задача 2

# %%
import requests

urls = [
    'http://www.python.org',
    'https://docs.python.org/3/',
    'https://docs.python.org/3/whatsnew/3.7.html',
    'https://docs.python.org/3/tutorial/index.html',
    'https://docs.python.org/3/library/index.html',
    'https://docs.python.org/3/reference/index.html',
    'https://docs.python.org/3/using/index.html',
    'https://docs.python.org/3/howto/index.html',
    'https://docs.python.org/3/installing/index.html',
    'https://docs.python.org/3/distributing/index.html',
]

def info2(results):
    print(f'results: {len(results)}, total lenght: {sum([len(i) for i in results])}')

# %%
@timer
def sync2(_urls):
    results = []
    for url in _urls:
        with requests.Session() as session:
            src = session.get(url)
            results.append(src.content)
    return info2(results)

sync2(urls)
# Out:
# results: 10, total lenght: 603371
# Time: 1.94346 sec (sync2)

# %%
@timer
def threaded2(_urls):
    results = []
    lock = Lock()  # Создаем объект блокировки
    
    # Функция для выполнения в потоке
    def worker(url):
        with requests.Session() as session:
            src = session.get(url)
            with lock:  # Блокируем доступ к общему ресурсу results
                results.append(src.content)
    
    # Создание и запуск потоков для вызова функции square
    threads = []
    for url in _urls:
        thread = Thread(target=worker, args=(url,))
        thread.start()
        threads.append(thread)
    
    # Ожидание завершения всех потоков
    for thread in threads:
        thread.join()

    return info2(results)

threaded2(urls)
# Out:
# results: 10, total lenght: 603371
# Time: 0.29763 sec (threaded2)

# %% [markdown]
# ### Пояснения
#
# `threading.Thread()` - создает новый поток, пока неактивный
# `start()` - используется для запуска созданного потока
# `join()` - блокирует выполнение потока, который его вызвал, до тех пор пока не завершится поток, метод которого был вызван
#
# У метода `join()` есть аргумент `timeout` - По умолчанию None, можно передать в него float

# %%
def myfunc(a, b):
    time.sleep(2.5)
    print('сумма :', a + b)
    
thr1 = Thread(target = myfunc, args = (1, 2), daemon=True)
thr1.start()
thr1.join(0.125)

if thr1.is_alive():
    print('поток не успел завершиться')
else:
    print('вычисления завершены')
# Out:
# поток не успел завершиться
# сумма : 3

# %% [markdown]
# ### Остановка потока

# %%
stop = False 

def myfunc():
    global stop
    while stop == False:
        pass
        
thr1 = Thread(target = myfunc) 
thr1.start() 

stop = True

while thr1.is_alive() == True: 
    pass
print('поток завершился')
# Out:
# поток завершился

# %% [markdown]
# ### Задача 3 - запись в БД

# %%
import sqlite3

db_file = "my_database.db"
table_name = 'my_table'

def recreate_table():
    conn_main = sqlite3.connect(db_file)
    cursor_main = conn_main.cursor()
    cursor_main.execute("DROP TABLE IF EXISTS my_table")
    cursor_main.execute("CREATE TABLE my_table (thread_id INTEGER, value TEXT)")
    conn_main.commit()
    conn_main.close()
    print('table recreated')


def worker_thread(thread_id):
    # Each thread gets its own connection
    conn = sqlite3.connect(db_file, check_same_thread=False)
    cursor = conn.cursor()

    try:
        # Perform database operations
        cursor.execute(f"INSERT INTO my_table (thread_id, value) VALUES (?, ?)", (thread_id, f"data_from_thread_{thread_id}"))
        conn.commit()
        print(f"Thread {thread_id}: Data inserted.")
    except Exception as e:
        print(f"Thread {thread_id}: Error - {e}")
        conn.rollback()
    finally:
        conn.close()


@timer
def threaded3(n):
    threads = []
    for i in range(n):
        thread = Thread(target=worker_thread, args=(i,))
        threads.append(thread)
        thread.start()

    for thread in threads:
        thread.join()

    print("All threads finished.")


recreate_table()
threaded3(555)
# Out:
# table recreated
# Thread 0: Data inserted.
# Thread 77: Data inserted.
# Thread 125: Data inserted.
# Thread 177: Data inserted.
# Thread 230: Data inserted.
# Thread 271: Data inserted.
# Thread 288: Data inserted.
# Thread 328: Data inserted.
# Thread 362: Data inserted.
# Thread 407: Data inserted.
# Thread 471: Data inserted.
# Thread 520: Data inserted.
# Thread 13: Data inserted.
# Thread 380: Data inserted.
# Thread 102: Data inserted.
# Thread 62: Data inserted.
# Thread 168: Data inserted.
# Thread 316: Data inserted.
# Thread 448: Data inserted.
# Thread 504: Data inserted.
# Thread 228: Data inserted.
# Thread 70: Data inserted.
# Thread 4: Data inserted.
# Thread 148: Data inserted.
# Thread 120: Data inserted.
# Thread 534: Data inserted.
# Thread 88: Data inserted.
# Thread 313: Data inserted.
# Thread 69: Data inserted.
# Thread 160: Data inserted.
# Thread 232: Data inserted.
# Thread 182: Data inserted.
# Thread 35: Data inserted.
# Thread 14: Data inserted.
# Thread 94: Data inserted.
# Thread 218: Data inserted.
# Thread 522: Data inserted.
# Thread 144: Data inserted.
# Thread 74: Data inserted.
# Thread 78: Data inserted.
# Thread 301: Data inserted.
# Thread 118: Data inserted.
# Thread 192: Data inserted.
# Thread 23: Data inserted.
# Thread 172: Data inserted.
# Thread 414: Data inserted.
# Thread 461: Data inserted.
# Thread 417: Data inserted.
# Thread 312: Data inserted.
# Thread 317: Data inserted.
# Thread 524: Data inserted.
# Thread 130: Data inserted.
# Thread 485: Data inserted.
# Thread 503: Data inserted.
# Thread 439: Data inserted.
# Thread 226: Data inserted.
# Thread 489: Data inserted.
# Thread 128: Data inserted.
# Thread 132: Data inserted.
# Thread 140: Data inserted.
# Thread 253: Data inserted.
# Thread 526: Data inserted.
# Thread 529: Data inserted.
# Thread 338: Data inserted.
# Thread 11: Data inserted.
# Thread 83: Data inserted.
# Thread 245: Data inserted.
# Thread 310: Data inserted.
# Thread 419: Data inserted.
# Thread 435: Data inserted.
# Thread 90: Data inserted.
# Thread 198: Data inserted.
# Thread 276: Data inserted.
# Thread 418: Data inserted.
# Thread 345: Data inserted.
# Thread 386: Data inserted.
# Thread 293: Data inserted.
# Thread 501: Data inserted.
# Thread 532: Data inserted.
# Thread 515: Data inserted.
# Thread 429: Data inserted.
# Thread 487: Data inserted.
# Thread 350: Data inserted.
# Thread 291: Data inserted.
# Thread 171: Data inserted.
# Thread 437: Data inserted.
# Thread 56: Data inserted.
# Thread 278: Data inserted.
# Thread 381: Data inserted.
# Thread 145: Data inserted.
# Thread 498: Data inserted.
# Thread 325: Data inserted.
# Thread 540: Data inserted.
# Thread 65: Data inserted.
# Thread 122: Data inserted.
# Thread 315: Data inserted.
# Thread 281: Data inserted.
# Thread 55: Data inserted.
# Thread 426: Data inserted.
# Thread 217: Data inserted.
# Thread 525: Data inserted.
# Thread 453: Data inserted.
# Thread 521: Data inserted.
# Thread 133: Data inserted.
# Thread 273: Data inserted.
# Thread 52: Data inserted.
# Thread 275: Data inserted.
# Thread 233: Data inserted.
# Thread 272: Data inserted.
# Thread 343: Data inserted.
# Thread 263: Data inserted.
# Thread 170: Data inserted.
# Thread 514: Data inserted.
# Thread 389: Data inserted.
# Thread 238: Data inserted.
# Thread 368: Data inserted.
# Thread 397: Data inserted.
# Thread 298: Data inserted.
# Thread 376: Data inserted.
# Thread 219: Data inserted.
# Thread 139: Data inserted.
# Thread 138: Data inserted.
# Thread 21: Data inserted.
# Thread 438: Data inserted.
# Thread 404: Data inserted.
# Thread 491: Data inserted.
# Thread 107: Data inserted.
# Thread 150: Data inserted.
# Thread 22: Data inserted.
# Thread 223: Data inserted.
# Thread 149: Data inserted.
# Thread 283: Data inserted.
# Thread 420: Data inserted.
# Thread 422: Data inserted.
# Thread 40: Data inserted.
# Thread 478: Data inserted.
# Thread 411: Data inserted.
# Thread 15: Data inserted.
# Thread 57: Data inserted.
# Thread 154: Data inserted.
# Thread 116: Data inserted.
# Thread 302: Data inserted.
# Thread 221: Data inserted.
# Thread 199: Data inserted.
# Thread 349: Data inserted.
# Thread 392: Data inserted.
# Thread 260: Data inserted.
# Thread 333: Data inserted.
# Thread 26: Data inserted.
# Thread 104: Data inserted.
# Thread 47: Data inserted.
# Thread 38: Data inserted.
# Thread 458: Data inserted.
# Thread 468: Data inserted.
# Thread 530: Data inserted.
# Thread 67: Data inserted.
# Thread 180: Data inserted.
# Thread 45: Data inserted.
# Thread 188: Data inserted.
# Thread 292: Data inserted.
# Thread 106: Data inserted.
# Thread 519: Data inserted.
# Thread 364: Data inserted.
# Thread 10: Data inserted.
# Thread 309: Data inserted.
# Thread 99: Data inserted.
# Thread 251: Data inserted.
# Thread 523: Data inserted.
# Thread 549: Data inserted.
# Thread 167: Data inserted.
# Thread 332: Data inserted.
# Thread 477: Data inserted.
# Thread 59: Data inserted.
# Thread 164: Data inserted.
# Thread 68: Data inserted.
# Thread 463: Data inserted.
# Thread 269: Data inserted.
# Thread 242: Data inserted.
# Thread 378: Data inserted.
# Thread 257: Data inserted.
# Thread 201: Data inserted.
# Thread 41: Data inserted.
# Thread 324: Data inserted.
# Thread 203: Data inserted.
# Thread 492: Data inserted.
# Thread 545: Data inserted.
# Thread 307: Data inserted.
# Thread 481: Data inserted.
# Thread 20: Data inserted.
# Thread 37: Data inserted.
# Thread 371: Data inserted.
# Thread 507: Data inserted.
# Thread 282: Data inserted.
# Thread 270: Data inserted.
# Thread 179: Data inserted.
# Thread 222: Data inserted.
# Thread 484: Data inserted.
# Thread 434: Data inserted.
# Thread 359: Data inserted.
# Thread 166: Data inserted.
# Thread 341: Data inserted.
# Thread 28: Data inserted.
# Thread 352: Data inserted.
# Thread 29: Data inserted.
# Thread 373: Data inserted.
# Thread 460: Data inserted.
# Thread 84: Data inserted.
# Thread 54: Data inserted.
# Thread 340: Data inserted.
# Thread 175: Data inserted.
# Thread 239: Data inserted.
# Thread 213: Data inserted.
# Thread 424: Data inserted.
# Thread 395: Data inserted.
# Thread 467: Data inserted.
# Thread 234: Data inserted.
# Thread 152: Data inserted.
# Thread 287: Data inserted.
# Thread 123: Data inserted.
# Thread 387: Data inserted.
# Thread 3: Data inserted.
# Thread 479: Data inserted.
# Thread 243: Data inserted.
# Thread 220: Data inserted.
# Thread 206: Data inserted.
# Thread 415: Data inserted.
# Thread 511: Data inserted.
# Thread 6: Data inserted.
# Thread 93: Data inserted.
# Thread 109: Data inserted.
# Thread 204: Data inserted.
# Thread 205: Data inserted.
# Thread 197: Data inserted.
# Thread 356: Data inserted.
# Thread 244: Data inserted.
# Thread 290: Data inserted.
# Thread 27: Data inserted.
# Thread 432: Data inserted.
# Thread 410: Data inserted.
# Thread 9: Data inserted.
# Thread 543: Data inserted.
# Thread 143: Data inserted.
# Thread 308: Data inserted.
# Thread 480: Data inserted.
# Thread 240: Data inserted.
# Thread 51: Data inserted.
# Thread 202: Data inserted.
# Thread 394: Data inserted.
# Thread 12: Data inserted.
# Thread 25: Data inserted.
# Thread 36: Data inserted.
# Thread 357: Data inserted.
# Thread 268: Data inserted.
# Thread 476: Data inserted.
# Thread 451: Data inserted.
# Thread 370: Data inserted.
# Thread 121: Data inserted.
# Thread 58: Data inserted.
# Thread 542: Data inserted.
# Thread 194: Data inserted.
# Thread 63: Data inserted.
# Thread 494: Data inserted.
# Thread 190: Data inserted.
# Thread 495: Data inserted.
# Thread 72: Data inserted.
# Thread 493: Data inserted.
# Thread 482: Data inserted.
# Thread 509: Data inserted.
# Thread 466: Data inserted.
# Thread 100: Data inserted.
# Thread 452: Data inserted.
# Thread 266: Data inserted.
# Thread 427: Data inserted.
# Thread 517: Data inserted.
# Thread 546: Data inserted.
# Thread 76: Data inserted.
# Thread 5: Data inserted.
# Thread 48: Data inserted.
# Thread 87: Data inserted.
# Thread 377: Data inserted.
# Thread 146: Data inserted.
# Thread 246: Data inserted.
# Thread 200: Data inserted.
# Thread 85: Data inserted.
# Thread 374: Data inserted.
# Thread 189: Data inserted.
# Thread 262: Data inserted.
# Thread 554: Data inserted.
# Thread 115: Data inserted.
# Thread 101: Data inserted.
# Thread 412: Data inserted.
# Thread 158: Data inserted.
# Thread 445: Data inserted.
# Thread 363: Data inserted.
# Thread 227: Data inserted.
# Thread 60: Data inserted.
# Thread 173: Data inserted.
# Thread 500: Data inserted.
# Thread 110: Data inserted.
# Thread 354: Data inserted.
# Thread 209: Data inserted.
# Thread 533: Data inserted.
# Thread 428: Data inserted.
# Thread 44: Data inserted.
# Thread 402: Data inserted.
# Thread 156: Data inserted.
# Thread 360: Data inserted.
# Thread 127: Data inserted.
# Thread 196: Data inserted.
# Thread 433: Data inserted.
# Thread 396: Data inserted.
# Thread 185: Data inserted.
# Thread 8: Data inserted.
# Thread 413: Data inserted.
# Thread 553: Data inserted.
# Thread 330: Data inserted.
# Thread 42: Data inserted.
# Thread 225: Data inserted.
# Thread 79: Data inserted.
# Thread 486: Data inserted.
# Thread 512: Data inserted.
# Thread 550: Data inserted.
# Thread 280: Data inserted.
# Thread 95: Data inserted.
# Thread 285: Data inserted.
# Thread 284: Data inserted.
# Thread 473: Data inserted.
# Thread 50: Data inserted.
# Thread 108: Data inserted.
# Thread 124: Data inserted.
# Thread 91: Data inserted.
# Thread 446: Data inserted.
# Thread 538: Data inserted.
# Thread 75: Data inserted.
# Thread 30: Data inserted.
# Thread 183: Data inserted.
# Thread 247: Data inserted.
# Thread 441: Data inserted.
# Thread 547: Data inserted.
# Thread 49: Data inserted.
# Thread 114: Data inserted.
# Thread 141: Data inserted.
# Thread 297: Data inserted.
# Thread 252: Data inserted.
# Thread 151: Data inserted.
# Thread 267: Data inserted.
# Thread 459: Data inserted.
# Thread 191: Data inserted.
# Thread 71: Data inserted.
# Thread 442: Data inserted.
# Thread 518: Data inserted.
# Thread 294: Data inserted.
# Thread 286: Data inserted.
# Thread 86: Data inserted.
# Thread 295: Data inserted.
# Thread 256: Data inserted.
# Thread 131: Data inserted.
# Thread 365: Data inserted.
# Thread 296: Data inserted.
# Thread 516: Data inserted.
# Thread 229: Data inserted.
# Thread 508: Data inserted.
# Thread 335: Data inserted.
# Thread 303: Data inserted.
# Thread 506: Data inserted.
# Thread 236: Data inserted.
# Thread 16: Data inserted.
# Thread 235: Data inserted.
# Thread 157: Data inserted.
# Thread 430: Data inserted.
# Thread 449: Data inserted.
# Thread 344: Data inserted.
# Thread 388: Data inserted.
# Thread 135: Data inserted.
# Thread 208: Data inserted.
# Thread 289: Error - database is locked
# Thread 32: Error - database is locked
# Thread 33: Data inserted.
# Thread 19: Error - database is locked
# Thread 43: Error - database is locked
# Thread 237: Data inserted.
# Thread 39: Error - database is locked
# Thread 82: Error - database is locked
# Thread 165: Data inserted.
# Thread 178: Data inserted.
# Thread 187: Data inserted.
# Thread 161: Error - database is locked
# Thread 261: Data inserted.
# Thread 431: Data inserted.
# Thread 126: Error - database is locked
# Thread 327: Error - database is locked
# Thread 159: Error - database is locked
# Thread 7: Error - database is locked
# Thread 98: Error - database is locked
# Thread 1: Error - database is locked
# Thread 279: Data inserted.
# Thread 383: Data inserted.
# Thread 24: Error - database is locked
# Thread 80: Error - database is locked
# Thread 113: Error - database is locked
# Thread 17: Error - database is locked
# Thread 89: Error - database is locked
# Thread 34: Error - database is locked
# Thread 306: Data inserted.
# Thread 46: Error - database is locked
# Thread 2: Error - database is locked
# Thread 195: Data inserted.
# Thread 18: Data inserted.
# Thread 421: Error - database is locked
# Thread 155: Error - database is locked
# Thread 416: Error - database is locked
# Thread 499: Error - database is locked
# Thread 259: Data inserted.
# Thread 277: Error - database is locked
# Thread 119: Error - database is locked
# Thread 31: Error - database is locked
# Thread 337: Error - database is locked
# Thread 264: Data inserted.
# Thread 61: Error - database is locked
# Thread 329: Error - database is locked
# Thread 311: Data inserted.
# Thread 502: Error - database is locked
# Thread 367: Error - database is locked
# Thread 331: Error - database is locked
# Thread 129: Error - database is locked
# Thread 336: Error - database is locked
# Thread 454: Data inserted.
# Thread 470: Error - database is locked
# Thread 342: Error - database is locked
# Thread 137: Error - database is locked
# Thread 142: Error - database is locked
# Thread 385: Error - database is locked
# Thread 163: Error - database is locked
# Thread 250: Error - database is locked
# Thread 497: Error - database is locked
# Thread 483: Error - database is locked
# Thread 136: Error - database is locked
# Thread 96: Error - database is locked
# Thread 527: Error - database is locked
# Thread 475: Data inserted.
# Thread 305: Error - database is locked
# Thread 314: Error - database is locked
# Thread 366: Error - database is locked
# Thread 347: Error - database is locked
# Thread 103: Error - database is locked
# Thread 111: Error - database is locked
# Thread 73: Error - database is locked
# Thread 274: Error - database is locked
# Thread 544: Error - database is locked
# Thread 97: Error - database is locked
# Thread 64: Error - database is locked
# Thread 181: Data inserted.
# Thread 300: Error - database is locked
# Thread 462: Error - database is locked
# Thread 66: Error - database is locked
# Thread 321: Error - database is locked
# Thread 53: Error - database is locked
# Thread 174: Error - database is locked
# Thread 552: Error - database is locked
# Thread 231: Error - database is locked
# Thread 513: Error - database is locked
# Thread 457: Error - database is locked
# Thread 265: Error - database is locked
# Thread 455: Error - database is locked
# Thread 443: Error - database is locked
# Thread 212: Error - database is locked
# Thread 409: Error - database is locked
# Thread 153: Error - database is locked
# Thread 440: Error - database is locked
# Thread 505: Error - database is locked
# Thread 81: Error - database is locked
# Thread 536: Error - database is locked
# Thread 551: Data inserted.
# Thread 358: Error - database is locked
# Thread 474: Error - database is locked
# Thread 490: Error - database is locked
# Thread 353: Error - database is locked
# Thread 405: Data inserted.
# Thread 408: Error - database is locked
# Thread 169: Error - database is locked
# Thread 528: Error - database is locked
# Thread 403: Error - database is locked
# Thread 162: Data inserted.
# Thread 193: Data inserted.
# Thread 469: Error - database is locked
# Thread 510: Error - database is locked
# Thread 369: Error - database is locked
# Thread 184: Error - database is locked
# Thread 214: Error - database is locked
# Thread 450: Data inserted.
# Thread 92: Error - database is locked
# Thread 464: Error - database is locked
# Thread 379: Error - database is locked
# Thread 400: Error - database is locked
# Thread 537: Error - database is locked
# Thread 216: Error - database is locked
# Thread 472: Error - database is locked
# Thread 531: Error - database is locked
# Thread 210: Error - database is locked
# Thread 393: Error - database is locked
# Thread 382: Error - database is locked
# Thread 355: Error - database is locked
# Thread 322: Error - database is locked
# Thread 541: Data inserted.
# Thread 117: Error - database is locked
# Thread 423: Error - database is locked
# Thread 304: Error - database is locked
# Thread 299: Error - database is locked
# Thread 444: Error - database is locked
# Thread 105: Error - database is locked
# Thread 254: Error - database is locked
# Thread 390: Error - database is locked
# Thread 425: Error - database is locked
# Thread 351: Error - database is locked
# Thread 258: Error - database is locked
# Thread 465: Error - database is locked
# Thread 241: Error - database is locked
# Thread 186: Error - database is locked
# Thread 496: Error - database is locked
# Thread 399: Error - database is locked
# Thread 391: Error - database is locked
# Thread 456: Error - database is locked
# Thread 372: Error - database is locked
# Thread 548: Error - database is locked
# Thread 375: Error - database is locked
# Thread 398: Error - database is locked
# Thread 318: Error - database is locked
# Thread 249: Error - database is locked
# Thread 224: Error - database is locked
# Thread 134: Error - database is locked
# Thread 406: Error - database is locked
# Thread 539: Data inserted.
# Thread 436: Error - database is locked
# Thread 339: Data inserted.
# Thread 361: Data inserted.
# Thread 207: Error - database is locked
# Thread 255: Error - database is locked
# Thread 334: Error - database is locked
# Thread 401: Data inserted.
# Thread 248: Error - database is locked
# Thread 535: Error - database is locked
# Thread 348: Error - database is locked
# Thread 211: Error - database is locked
# Thread 320: Error - database is locked
# Thread 319: Data inserted.
# Thread 384: Error - database is locked
# Thread 112: Error - database is locked
# Thread 323: Error - database is locked
# Thread 326: Data inserted.
# Thread 147: Error - database is locked
# Thread 215: Error - database is locked
# Thread 346: Data inserted.
# Thread 447: Data inserted.
# Thread 176: Error - database is locked
# Thread 488: Data inserted.
# All threads finished.
# Time: 6.66007 sec (threaded3)

# %%
@timer
def synced3(n):

    for i in range(n):
        conn = sqlite3.connect(db_file)
        cursor = conn.cursor()
    
        try:
            # Perform database operations
            cursor.execute(f"INSERT INTO my_table (thread_id, value) VALUES (?, ?);", (i, f"data_from_thread_{i}"))
            conn.commit()
            print(f"Iter {i}: Data inserted.")
        except Exception as e:
            print(f"Iter {i}: Error - {e}")
            conn.rollback()
        finally:
            conn.close()
    
    print("All finished.")


recreate_table()
synced3(555)
# Out:
# table recreated
# Iter 0: Data inserted.
# Iter 1: Data inserted.
# Iter 2: Data inserted.
# Iter 3: Data inserted.
# Iter 4: Data inserted.
# Iter 5: Data inserted.
# Iter 6: Data inserted.
# Iter 7: Data inserted.
# Iter 8: Data inserted.
# Iter 9: Data inserted.
# Iter 10: Data inserted.
# Iter 11: Data inserted.
# Iter 12: Data inserted.
# Iter 13: Data inserted.
# Iter 14: Data inserted.
# Iter 15: Data inserted.
# Iter 16: Data inserted.
# Iter 17: Data inserted.
# Iter 18: Data inserted.
# Iter 19: Data inserted.
# Iter 20: Data inserted.
# Iter 21: Data inserted.
# Iter 22: Data inserted.
# Iter 23: Data inserted.
# Iter 24: Data inserted.
# Iter 25: Data inserted.
# Iter 26: Data inserted.
# Iter 27: Data inserted.
# Iter 28: Data inserted.
# Iter 29: Data inserted.
# Iter 30: Data inserted.
# Iter 31: Data inserted.
# Iter 32: Data inserted.
# Iter 33: Data inserted.
# Iter 34: Data inserted.
# Iter 35: Data inserted.
# Iter 36: Data inserted.
# Iter 37: Data inserted.
# Iter 38: Data inserted.
# Iter 39: Data inserted.
# Iter 40: Data inserted.
# Iter 41: Data inserted.
# Iter 42: Data inserted.
# Iter 43: Data inserted.
# Iter 44: Data inserted.
# Iter 45: Data inserted.
# Iter 46: Data inserted.
# Iter 47: Data inserted.
# Iter 48: Data inserted.
# Iter 49: Data inserted.
# Iter 50: Data inserted.
# Iter 51: Data inserted.
# Iter 52: Data inserted.
# Iter 53: Data inserted.
# Iter 54: Data inserted.
# Iter 55: Data inserted.
# Iter 56: Data inserted.
# Iter 57: Data inserted.
# Iter 58: Data inserted.
# Iter 59: Data inserted.
# Iter 60: Data inserted.
# Iter 61: Data inserted.
# Iter 62: Data inserted.
# Iter 63: Data inserted.
# Iter 64: Data inserted.
# Iter 65: Data inserted.
# Iter 66: Data inserted.
# Iter 67: Data inserted.
# Iter 68: Data inserted.
# Iter 69: Data inserted.
# Iter 70: Data inserted.
# Iter 71: Data inserted.
# Iter 72: Data inserted.
# Iter 73: Data inserted.
# Iter 74: Data inserted.
# Iter 75: Data inserted.
# Iter 76: Data inserted.
# Iter 77: Data inserted.
# Iter 78: Data inserted.
# Iter 79: Data inserted.
# Iter 80: Data inserted.
# Iter 81: Data inserted.
# Iter 82: Data inserted.
# Iter 83: Data inserted.
# Iter 84: Data inserted.
# Iter 85: Data inserted.
# Iter 86: Data inserted.
# Iter 87: Data inserted.
# Iter 88: Data inserted.
# Iter 89: Data inserted.
# Iter 90: Data inserted.
# Iter 91: Data inserted.
# Iter 92: Data inserted.
# Iter 93: Data inserted.
# Iter 94: Data inserted.
# Iter 95: Data inserted.
# Iter 96: Data inserted.
# Iter 97: Data inserted.
# Iter 98: Data inserted.
# Iter 99: Data inserted.
# Iter 100: Data inserted.
# Iter 101: Data inserted.
# Iter 102: Data inserted.
# Iter 103: Data inserted.
# Iter 104: Data inserted.
# Iter 105: Data inserted.
# Iter 106: Data inserted.
# Iter 107: Data inserted.
# Iter 108: Data inserted.
# Iter 109: Data inserted.
# Iter 110: Data inserted.
# Iter 111: Data inserted.
# Iter 112: Data inserted.
# Iter 113: Data inserted.
# Iter 114: Data inserted.
# Iter 115: Data inserted.
# Iter 116: Data inserted.
# Iter 117: Data inserted.
# Iter 118: Data inserted.
# Iter 119: Data inserted.
# Iter 120: Data inserted.
# Iter 121: Data inserted.
# Iter 122: Data inserted.
# Iter 123: Data inserted.
# Iter 124: Data inserted.
# Iter 125: Data inserted.
# Iter 126: Data inserted.
# Iter 127: Data inserted.
# Iter 128: Data inserted.
# Iter 129: Data inserted.
# Iter 130: Data inserted.
# Iter 131: Data inserted.
# Iter 132: Data inserted.
# Iter 133: Data inserted.
# Iter 134: Data inserted.
# Iter 135: Data inserted.
# Iter 136: Data inserted.
# Iter 137: Data inserted.
# Iter 138: Data inserted.
# Iter 139: Data inserted.
# Iter 140: Data inserted.
# Iter 141: Data inserted.
# Iter 142: Data inserted.
# Iter 143: Data inserted.
# Iter 144: Data inserted.
# Iter 145: Data inserted.
# Iter 146: Data inserted.
# Iter 147: Data inserted.
# Iter 148: Data inserted.
# Iter 149: Data inserted.
# Iter 150: Data inserted.
# Iter 151: Data inserted.
# Iter 152: Data inserted.
# Iter 153: Data inserted.
# Iter 154: Data inserted.
# Iter 155: Data inserted.
# Iter 156: Data inserted.
# Iter 157: Data inserted.
# Iter 158: Data inserted.
# Iter 159: Data inserted.
# Iter 160: Data inserted.
# Iter 161: Data inserted.
# Iter 162: Data inserted.
# Iter 163: Data inserted.
# Iter 164: Data inserted.
# Iter 165: Data inserted.
# Iter 166: Data inserted.
# Iter 167: Data inserted.
# Iter 168: Data inserted.
# Iter 169: Data inserted.
# Iter 170: Data inserted.
# Iter 171: Data inserted.
# Iter 172: Data inserted.
# Iter 173: Data inserted.
# Iter 174: Data inserted.
# Iter 175: Data inserted.
# Iter 176: Data inserted.
# Iter 177: Data inserted.
# Iter 178: Data inserted.
# Iter 179: Data inserted.
# Iter 180: Data inserted.
# Iter 181: Data inserted.
# Iter 182: Data inserted.
# Iter 183: Data inserted.
# Iter 184: Data inserted.
# Iter 185: Data inserted.
# Iter 186: Data inserted.
# Iter 187: Data inserted.
# Iter 188: Data inserted.
# Iter 189: Data inserted.
# Iter 190: Data inserted.
# Iter 191: Data inserted.
# Iter 192: Data inserted.
# Iter 193: Data inserted.
# Iter 194: Data inserted.
# Iter 195: Data inserted.
# Iter 196: Data inserted.
# Iter 197: Data inserted.
# Iter 198: Data inserted.
# Iter 199: Data inserted.
# Iter 200: Data inserted.
# Iter 201: Data inserted.
# Iter 202: Data inserted.
# Iter 203: Data inserted.
# Iter 204: Data inserted.
# Iter 205: Data inserted.
# Iter 206: Data inserted.
# Iter 207: Data inserted.
# Iter 208: Data inserted.
# Iter 209: Data inserted.
# Iter 210: Data inserted.
# Iter 211: Data inserted.
# Iter 212: Data inserted.
# Iter 213: Data inserted.
# Iter 214: Data inserted.
# Iter 215: Data inserted.
# Iter 216: Data inserted.
# Iter 217: Data inserted.
# Iter 218: Data inserted.
# Iter 219: Data inserted.
# Iter 220: Data inserted.
# Iter 221: Data inserted.
# Iter 222: Data inserted.
# Iter 223: Data inserted.
# Iter 224: Data inserted.
# Iter 225: Data inserted.
# Iter 226: Data inserted.
# Iter 227: Data inserted.
# Iter 228: Data inserted.
# Iter 229: Data inserted.
# Iter 230: Data inserted.
# Iter 231: Data inserted.
# Iter 232: Data inserted.
# Iter 233: Data inserted.
# Iter 234: Data inserted.
# Iter 235: Data inserted.
# Iter 236: Data inserted.
# Iter 237: Data inserted.
# Iter 238: Data inserted.
# Iter 239: Data inserted.
# Iter 240: Data inserted.
# Iter 241: Data inserted.
# Iter 242: Data inserted.
# Iter 243: Data inserted.
# Iter 244: Data inserted.
# Iter 245: Data inserted.
# Iter 246: Data inserted.
# Iter 247: Data inserted.
# Iter 248: Data inserted.
# Iter 249: Data inserted.
# Iter 250: Data inserted.
# Iter 251: Data inserted.
# Iter 252: Data inserted.
# Iter 253: Data inserted.
# Iter 254: Data inserted.
# Iter 255: Data inserted.
# Iter 256: Data inserted.
# Iter 257: Data inserted.
# Iter 258: Data inserted.
# Iter 259: Data inserted.
# Iter 260: Data inserted.
# Iter 261: Data inserted.
# Iter 262: Data inserted.
# Iter 263: Data inserted.
# Iter 264: Data inserted.
# Iter 265: Data inserted.
# Iter 266: Data inserted.
# Iter 267: Data inserted.
# Iter 268: Data inserted.
# Iter 269: Data inserted.
# Iter 270: Data inserted.
# Iter 271: Data inserted.
# Iter 272: Data inserted.
# Iter 273: Data inserted.
# Iter 274: Data inserted.
# Iter 275: Data inserted.
# Iter 276: Data inserted.
# Iter 277: Data inserted.
# Iter 278: Data inserted.
# Iter 279: Data inserted.
# Iter 280: Data inserted.
# Iter 281: Data inserted.
# Iter 282: Data inserted.
# Iter 283: Data inserted.
# Iter 284: Data inserted.
# Iter 285: Data inserted.
# Iter 286: Data inserted.
# Iter 287: Data inserted.
# Iter 288: Data inserted.
# Iter 289: Data inserted.
# Iter 290: Data inserted.
# Iter 291: Data inserted.
# Iter 292: Data inserted.
# Iter 293: Data inserted.
# Iter 294: Data inserted.
# Iter 295: Data inserted.
# Iter 296: Data inserted.
# Iter 297: Data inserted.
# Iter 298: Data inserted.
# Iter 299: Data inserted.
# Iter 300: Data inserted.
# Iter 301: Data inserted.
# Iter 302: Data inserted.
# Iter 303: Data inserted.
# Iter 304: Data inserted.
# Iter 305: Data inserted.
# Iter 306: Data inserted.
# Iter 307: Data inserted.
# Iter 308: Data inserted.
# Iter 309: Data inserted.
# Iter 310: Data inserted.
# Iter 311: Data inserted.
# Iter 312: Data inserted.
# Iter 313: Data inserted.
# Iter 314: Data inserted.
# Iter 315: Data inserted.
# Iter 316: Data inserted.
# Iter 317: Data inserted.
# Iter 318: Data inserted.
# Iter 319: Data inserted.
# Iter 320: Data inserted.
# Iter 321: Data inserted.
# Iter 322: Data inserted.
# Iter 323: Data inserted.
# Iter 324: Data inserted.
# Iter 325: Data inserted.
# Iter 326: Data inserted.
# Iter 327: Data inserted.
# Iter 328: Data inserted.
# Iter 329: Data inserted.
# Iter 330: Data inserted.
# Iter 331: Data inserted.
# Iter 332: Data inserted.
# Iter 333: Data inserted.
# Iter 334: Data inserted.
# Iter 335: Data inserted.
# Iter 336: Data inserted.
# Iter 337: Data inserted.
# Iter 338: Data inserted.
# Iter 339: Data inserted.
# Iter 340: Data inserted.
# Iter 341: Data inserted.
# Iter 342: Data inserted.
# Iter 343: Data inserted.
# Iter 344: Data inserted.
# Iter 345: Data inserted.
# Iter 346: Data inserted.
# Iter 347: Data inserted.
# Iter 348: Data inserted.
# Iter 349: Data inserted.
# Iter 350: Data inserted.
# Iter 351: Data inserted.
# Iter 352: Data inserted.
# Iter 353: Data inserted.
# Iter 354: Data inserted.
# Iter 355: Data inserted.
# Iter 356: Data inserted.
# Iter 357: Data inserted.
# Iter 358: Data inserted.
# Iter 359: Data inserted.
# Iter 360: Data inserted.
# Iter 361: Data inserted.
# Iter 362: Data inserted.
# Iter 363: Data inserted.
# Iter 364: Data inserted.
# Iter 365: Data inserted.
# Iter 366: Data inserted.
# Iter 367: Data inserted.
# Iter 368: Data inserted.
# Iter 369: Data inserted.
# Iter 370: Data inserted.
# Iter 371: Data inserted.
# Iter 372: Data inserted.
# Iter 373: Data inserted.
# Iter 374: Data inserted.
# Iter 375: Data inserted.
# Iter 376: Data inserted.
# Iter 377: Data inserted.
# Iter 378: Data inserted.
# Iter 379: Data inserted.
# Iter 380: Data inserted.
# Iter 381: Data inserted.
# Iter 382: Data inserted.
# Iter 383: Data inserted.
# Iter 384: Data inserted.
# Iter 385: Data inserted.
# Iter 386: Data inserted.
# Iter 387: Data inserted.
# Iter 388: Data inserted.
# Iter 389: Data inserted.
# Iter 390: Data inserted.
# Iter 391: Data inserted.
# Iter 392: Data inserted.
# Iter 393: Data inserted.
# Iter 394: Data inserted.
# Iter 395: Data inserted.
# Iter 396: Data inserted.
# Iter 397: Data inserted.
# Iter 398: Data inserted.
# Iter 399: Data inserted.
# Iter 400: Data inserted.
# Iter 401: Data inserted.
# Iter 402: Data inserted.
# Iter 403: Data inserted.
# Iter 404: Data inserted.
# Iter 405: Data inserted.
# Iter 406: Data inserted.
# Iter 407: Data inserted.
# Iter 408: Data inserted.
# Iter 409: Data inserted.
# Iter 410: Data inserted.
# Iter 411: Data inserted.
# Iter 412: Data inserted.
# Iter 413: Data inserted.
# Iter 414: Data inserted.
# Iter 415: Data inserted.
# Iter 416: Data inserted.
# Iter 417: Data inserted.
# Iter 418: Data inserted.
# Iter 419: Data inserted.
# Iter 420: Data inserted.
# Iter 421: Data inserted.
# Iter 422: Data inserted.
# Iter 423: Data inserted.
# Iter 424: Data inserted.
# Iter 425: Data inserted.
# Iter 426: Data inserted.
# Iter 427: Data inserted.
# Iter 428: Data inserted.
# Iter 429: Data inserted.
# Iter 430: Data inserted.
# Iter 431: Data inserted.
# Iter 432: Data inserted.
# Iter 433: Data inserted.
# Iter 434: Data inserted.
# Iter 435: Data inserted.
# Iter 436: Data inserted.
# Iter 437: Data inserted.
# Iter 438: Data inserted.
# Iter 439: Data inserted.
# Iter 440: Data inserted.
# Iter 441: Data inserted.
# Iter 442: Data inserted.
# Iter 443: Data inserted.
# Iter 444: Data inserted.
# Iter 445: Data inserted.
# Iter 446: Data inserted.
# Iter 447: Data inserted.
# Iter 448: Data inserted.
# Iter 449: Data inserted.
# Iter 450: Data inserted.
# Iter 451: Data inserted.
# Iter 452: Data inserted.
# Iter 453: Data inserted.
# Iter 454: Data inserted.
# Iter 455: Data inserted.
# Iter 456: Data inserted.
# Iter 457: Data inserted.
# Iter 458: Data inserted.
# Iter 459: Data inserted.
# Iter 460: Data inserted.
# Iter 461: Data inserted.
# Iter 462: Data inserted.
# Iter 463: Data inserted.
# Iter 464: Data inserted.
# Iter 465: Data inserted.
# Iter 466: Data inserted.
# Iter 467: Data inserted.
# Iter 468: Data inserted.
# Iter 469: Data inserted.
# Iter 470: Data inserted.
# Iter 471: Data inserted.
# Iter 472: Data inserted.
# Iter 473: Data inserted.
# Iter 474: Data inserted.
# Iter 475: Data inserted.
# Iter 476: Data inserted.
# Iter 477: Data inserted.
# Iter 478: Data inserted.
# Iter 479: Data inserted.
# Iter 480: Data inserted.
# Iter 481: Data inserted.
# Iter 482: Data inserted.
# Iter 483: Data inserted.
# Iter 484: Data inserted.
# Iter 485: Data inserted.
# Iter 486: Data inserted.
# Iter 487: Data inserted.
# Iter 488: Data inserted.
# Iter 489: Data inserted.
# Iter 490: Data inserted.
# Iter 491: Data inserted.
# Iter 492: Data inserted.
# Iter 493: Data inserted.
# Iter 494: Data inserted.
# Iter 495: Data inserted.
# Iter 496: Data inserted.
# Iter 497: Data inserted.
# Iter 498: Data inserted.
# Iter 499: Data inserted.
# Iter 500: Data inserted.
# Iter 501: Data inserted.
# Iter 502: Data inserted.
# Iter 503: Data inserted.
# Iter 504: Data inserted.
# Iter 505: Data inserted.
# Iter 506: Data inserted.
# Iter 507: Data inserted.
# Iter 508: Data inserted.
# Iter 509: Data inserted.
# Iter 510: Data inserted.
# Iter 511: Data inserted.
# Iter 512: Data inserted.
# Iter 513: Data inserted.
# Iter 514: Data inserted.
# Iter 515: Data inserted.
# Iter 516: Data inserted.
# Iter 517: Data inserted.
# Iter 518: Data inserted.
# Iter 519: Data inserted.
# Iter 520: Data inserted.
# Iter 521: Data inserted.
# Iter 522: Data inserted.
# Iter 523: Data inserted.
# Iter 524: Data inserted.
# Iter 525: Data inserted.
# Iter 526: Data inserted.
# Iter 527: Data inserted.
# Iter 528: Data inserted.
# Iter 529: Data inserted.
# Iter 530: Data inserted.
# Iter 531: Data inserted.
# Iter 532: Data inserted.
# Iter 533: Data inserted.
# Iter 534: Data inserted.
# Iter 535: Data inserted.
# Iter 536: Data inserted.
# Iter 537: Data inserted.
# Iter 538: Data inserted.
# Iter 539: Data inserted.
# Iter 540: Data inserted.
# Iter 541: Data inserted.
# Iter 542: Data inserted.
# Iter 543: Data inserted.
# Iter 544: Data inserted.
# Iter 545: Data inserted.
# Iter 546: Data inserted.
# Iter 547: Data inserted.
# Iter 548: Data inserted.
# Iter 549: Data inserted.
# Iter 550: Data inserted.
# Iter 551: Data inserted.
# Iter 552: Data inserted.
# Iter 553: Data inserted.
# Iter 554: Data inserted.
# All finished.
# Time: 3.20273 sec (synced3)

# %% [markdown]
# # concurrent.futures

# %%
from concurrent.futures import ThreadPoolExecutor

# %%
with ThreadPoolExecutor(max_workers=2) as executor:
    future = executor.submit(pow, 5, 2)
    print(future.result())
# Out:
# 25

# %%
from concurrent.futures import as_completed
import urllib

# Извлечение контента одной страницы
def load_url(url, timeout):
    with urllib.request.urlopen(url, timeout=timeout) as conn:
        return conn.read()

@timer
def threaded3():
    results = []
    # Использование контекстного менеджера
    with ThreadPoolExecutor(max_workers=10) as executor:
        # Start the load operations and mark each future with its URL
        futures = [executor.submit(load_url, url, 60) for url in urls]
        for future in as_completed(futures):
            future_data = future.result()
            results.append(future_data)
    
    return info2(results)   

threaded3()
# Out:
# results: 10, total lenght: 603371
# Time: 0.29320 sec (threaded3)

# %% [markdown]
# #### Мэппинг вхдящих к выходящим результатам

# %%
@timer
def threaded41():
    # Использование контекстного менеджера
    with ThreadPoolExecutor(max_workers=5) as executor:
        # Start the load operations and mark each future with its URL
        future_to_url = {executor.submit(load_url, url, 60): url for url in urls}
        for future in as_completed(future_to_url):
            url = future_to_url[future]
            try:
                data = future.result()
            except Exception as exc:
                print('%r generated an exception: %s' % (url, exc))
            else:
                print('%r page is %d bytes' % (url, len(data)))

threaded41()
# Out:
# 'https://docs.python.org/3/tutorial/index.html' page is 35586 bytes
# 'https://docs.python.org/3/' page is 17833 bytes
# 'https://docs.python.org/3/library/index.html' page is 75846 bytes
# 'http://www.python.org' page is 49790 bytes
# 'https://docs.python.org/3/whatsnew/3.7.html' page is 319290 bytes
# 'https://docs.python.org/3/reference/index.html' page is 26263 bytes
# 'https://docs.python.org/3/using/index.html' page is 19342 bytes
# 'https://docs.python.org/3/howto/index.html' page is 17002 bytes
# 'https://docs.python.org/3/distributing/index.html' page is 11421 bytes
# 'https://docs.python.org/3/installing/index.html' page is 30998 bytes
# Time: 0.50874 sec (threaded41)

# %% [markdown]
# #### Без использования контектснго менеджера

# %%
def worker():
    print("Worker thread running")

pool = ThreadPoolExecutor(max_workers=2)

pool.submit(worker)
pool.submit(worker)

pool.shutdown(wait=True)

print("Main thread continuing to run")
# Out:
# Worker thread running
# Worker thread running
# Main thread continuing to run
