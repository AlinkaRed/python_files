# %%
import random
s = '0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxy'
res = []
for i in range(len(s)):
    res.append(s[i])

# %%
random.shuffle(res)
res
# Out:
# ['P',
#  '8',
#  'C',
#  '1',
#  'H',
#  'i',
#  '5',
#  'A',
#  'j',
#  'p',
#  's',
#  '9',
#  'u',
#  'h',
#  't',
#  'L',
#  'D',
#  'q',
#  'Y',
#  '0',
#  'v',
#  'J',
#  'Q',
#  'R',
#  'E',
#  'G',
#  'U',
#  'V',
#  'd',
#  '2',
#  'Z',
#  'b',
#  'm',
#  'N',
#  'f',
#  'r',
#  'S',
#  'l',
#  'B',
#  'k',
#  'W',
#  'o',
#  '7',
#  'I',
#  'a',
#  'M',
#  'K',
#  'e',
#  'T',
#  'X',
#  'w',
#  'O',
#  'g',
#  'c',
#  '3',
#  '4',
#  'y',
#  'x',
#  'n',
#  '6',
#  'F']

# %%
s=''.join(res)

# %%
s = '0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxy'
s1 = list(s)

# %%
random.randint(0, 55)
# Out:
# 51

# %%
s1.pop(10)
# Out:
# 'A'

# %%
a = (1,1192029,3)
def f(a,b,c,m):
    print (a*b*c+m)

# %%
m = 9
f(*a,m)
# Out:
# 3576096

# %%
def f (*a):
    print(sum(a))

# %%
f(*a,88)
# Out:
# 1192121

# %%
def fun (a,b,/,x,*,n):
    print(sum([a,b,])*n)
fun(1,2,3,n=4)
fun(2,3,x=8,n=9)
# Out:
# 12
# 45

# %%
def f (a,b,c=None):
    if c is None:
        c=[]
    print(a*b*c)
f(1,2,0)
# Out:
# 0

# %%
kw = [{'a':1,'b':2},{'a':9,'b':8}]

# %%
def f(a=None,b=None):
    print(a*b)
for i in kw:
    f(**i)
# Out:
# 2
# 72

# %%
a = 1, 2

# %%
def f(a: int):
    print(not a)

# %%
f(0)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
0 or 1 or 2
# Out:
# 1

# %%
0 and 1
# Out:
# 0

# %%
0 or 'a' or 555
# Out:
# 'a'

# %%
0 or ('a' and False)
# Out:
# False
