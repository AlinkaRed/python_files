# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\user\anaconda3\lib\site-packages (2.0.30)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy) (3.0.1)

# %% [markdown]
# # SQLalchemy

# %% [markdown]
# https://docs.sqlalchemy.org/en/20/orm/queryguide/

# %% [markdown]
# ## ORM - Object Relational Mapping

# %% [markdown]
# ## Mapping

# %%
from typing import List, Optional
from sqlalchemy import ForeignKey, String
from sqlalchemy.orm import DeclarativeBase, Mapped, Session, mapped_column, relationship


class Base(DeclarativeBase):
    pass


class Faculty(Base):
    __tablename__ = "faculty"

    id: Mapped[int] = mapped_column(primary_key=True)
    name: Mapped[str] = mapped_column(String(30))
    num: Mapped[int]

    courses: Mapped[List["Course"]] = relationship(back_populates="faculty", cascade="all, delete-orphan")

    def __repr__(self) -> str:
        return f"Faculty(id={self.id!r}, name={self.name!r}, num={self.num!r})"


class Course(Base):
    __tablename__ = "course"
    id: Mapped[int] = mapped_column(primary_key=True)
    num: Mapped[int]

    faculty_id: Mapped[int] = mapped_column(ForeignKey("faculty.id"))
    faculty: Mapped["Faculty"] = relationship(back_populates="courses")

    def __repr__(self) -> str:
        return f"Course(id={self.id!r}, num={self.num!r}, faculty={self.faculty.name!r})"

# %% [markdown]
# ## Engine

# %%
from sqlalchemy import create_engine

DB_HOST = 'localhost'
DB_PORT = 5432
DB_NAME = 'students'
DB_USER = 'postgres'
DB_PASSWORD = 'root'

engine = create_engine(f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}")

# %% [markdown]
# ## Direct SQL; Connection

# %%
from sqlalchemy import text

with engine.connect() as conn:
    result = conn.execute(text("select * from faculty"))
    print(result.all())
# Out:
# [(1, 51, 'ПИНЖ'), (2, 52, 'ФИИТ'), (3, 53, 'МЕХТЕХ'), (5, 39, 'IT4'), (6, 905, 'Test5'), (7, 906, 'Test6'), (8, 901, 'Test1'), (9, 902, 'Test2'), (4, 38, 'IT31')]

# %% [markdown]
# ## Direct SQL; Session

# %%
from sqlalchemy.orm import Session

stmt = text("SELECT id, name, num FROM faculty WHERE id > :var ORDER BY name")
with Session(engine) as session:
    result = session.execute(stmt, {"var": 2})
    for row in result:
        print(f"id: {row.id}  name: {row.name}  num: {row.num}")
# Out:
# id: 4  name: IT31  num: 38
# id: 5  name: IT4  num: 39
# id: 8  name: Test1  num: 901
# id: 9  name: Test2  num: 902
# id: 6  name: Test5  num: 905
# id: 7  name: Test6  num: 906
# id: 3  name: МЕХТЕХ  num: 53

# %% [markdown]
# # ORM

# %% [markdown]
# #### Logging

# %%
import logging
logging.basicConfig()

def log_on():
    logging.getLogger('sqlalchemy.engine').setLevel(logging.INFO)

def log_off():
    logging.getLogger('sqlalchemy.engine').setLevel(logging.ERROR)

log_on()

# %%
log_off()

# %% [markdown]
# ## Select

# %%
from sqlalchemy import select

stmt = select(Faculty).where(Faculty.name.in_(["ФИИТ", "ПИНЖ"]))
print(stmt)
# Out:
# SELECT faculty.id, faculty.name, faculty.num
# FROM faculty
# WHERE faculty.name IN (__[POSTCOMPILE_name_1])

# %%
from sqlalchemy.orm import Session
from sqlalchemy import select

with Session(engine) as session:
    stmt = select(Faculty).where(Faculty.name.in_(["ФИИТ", "ПИНЖ"]))
    for fac in session.scalars(stmt):
        print(fac)
        print(fac.courses)
# Out:
# Faculty(id=1, name='ПИНЖ', num=51)
# [Course(id=1, num=11, faculty='ПИНЖ'), Course(id=2, num=12, faculty='ПИНЖ'), Course(id=3, num=13, faculty='ПИНЖ'), Course(id=4, num=14, faculty='ПИНЖ'), Course(id=5, num=15, faculty='ПИНЖ')]
# Faculty(id=2, name='ФИИТ', num=52)
# [Course(id=6, num=21, faculty='ФИИТ'), Course(id=7, num=22, faculty='ФИИТ'), Course(id=8, num=23, faculty='ФИИТ'), Course(id=9, num=24, faculty='ФИИТ'), Course(id=10, num=25, faculty='ФИИТ')]

# %%
fac.id
# Out:
# 2

# %%
with Session(engine) as session:
    stmt = select(Course)
    for course in session.scalars(stmt):
        print(course, course.id, course.num, course.faculty.name)
# Out:
# Course(id=1, num=11, faculty='ПИНЖ') 1 11 ПИНЖ
# Course(id=2, num=12, faculty='ПИНЖ') 2 12 ПИНЖ
# Course(id=3, num=13, faculty='ПИНЖ') 3 13 ПИНЖ
# Course(id=4, num=14, faculty='ПИНЖ') 4 14 ПИНЖ
# Course(id=5, num=15, faculty='ПИНЖ') 5 15 ПИНЖ
# Course(id=6, num=21, faculty='ФИИТ') 6 21 ФИИТ
# Course(id=7, num=22, faculty='ФИИТ') 7 22 ФИИТ
# Course(id=8, num=23, faculty='ФИИТ') 8 23 ФИИТ
# Course(id=9, num=24, faculty='ФИИТ') 9 24 ФИИТ
# Course(id=10, num=25, faculty='ФИИТ') 10 25 ФИИТ
# Course(id=11, num=31, faculty='МЕХТЕХ') 11 31 МЕХТЕХ
# Course(id=12, num=32, faculty='МЕХТЕХ') 12 32 МЕХТЕХ
# Course(id=13, num=33, faculty='МЕХТЕХ') 13 33 МЕХТЕХ
# Course(id=14, num=34, faculty='МЕХТЕХ') 14 34 МЕХТЕХ
# Course(id=15, num=35, faculty='МЕХТЕХ') 15 35 МЕХТЕХ
# Course(id=16, num=389, faculty='IT31') 16 389 IT31

# %%
list(Course.__table__.columns)[0].name
# Out:
# 'id'

# %% [markdown]
# #### to dict

# %%
import pandas as pd

with Session(engine) as session:
    stmt = select(Course)
    for course in session.scalars(stmt).all():
        print(dict((col.name, getattr(course, col.name)) for col in Course.__table__.columns))
# Out:
# {'id': 1, 'num': 11, 'faculty_id': 1}
# {'id': 2, 'num': 12, 'faculty_id': 1}
# {'id': 3, 'num': 13, 'faculty_id': 1}
# {'id': 4, 'num': 14, 'faculty_id': 1}
# {'id': 5, 'num': 15, 'faculty_id': 1}
# {'id': 6, 'num': 21, 'faculty_id': 2}
# {'id': 7, 'num': 22, 'faculty_id': 2}
# {'id': 8, 'num': 23, 'faculty_id': 2}
# {'id': 9, 'num': 24, 'faculty_id': 2}
# {'id': 10, 'num': 25, 'faculty_id': 2}
# {'id': 11, 'num': 31, 'faculty_id': 3}
# {'id': 12, 'num': 32, 'faculty_id': 3}
# {'id': 13, 'num': 33, 'faculty_id': 3}
# {'id': 14, 'num': 34, 'faculty_id': 3}
# {'id': 15, 'num': 35, 'faculty_id': 3}
# {'id': 16, 'num': 389, 'faculty_id': 4}

# %% [markdown]
# #### Join

# %%
with Session(engine) as session:
    stmt = (
        select(Course)
            .join(Course.faculty)
            .where(Course.num == 21)
            .where(Faculty.name == "ФИИТ")
        )
    result = session.scalars(stmt).one()
    print(result)
# Out:
# Course(id=6, num=21, faculty='ФИИТ')

# %% [markdown]
# #### Limit, first, order_by, one, one_or_none

# %%
with Session(engine) as session:
    result = session.scalars(select(Faculty).order_by(Faculty.name).limit(1)).one_or_none()
    print(result)
# Out:
# Faculty(id=4, name='IT31', num=38)

# %% [markdown]
# #### execute vs scalars

# %%
with Session(engine) as session:
    query = select(Faculty.name, Faculty.id).order_by(Faculty.name)
    result = session.execute(query).first()
    print(result)
# Out:
# ('IT31', 4)

# %%
with Session(engine) as session:
    query = select(Faculty.name, Faculty.id).order_by(Faculty.name)
    result = session.scalars(query).all()
    print(result)
# Out:
# ['IT31', 'IT4', 'Test1', 'Test2', 'Test5', 'Test6', 'МЕХТЕХ', 'ПИНЖ', 'ФИИТ']

# %% [markdown]
# ### Columns

# %%
from sqlalchemy import select
from sqlalchemy.orm import load_only

with Session(engine) as session:
    stmt = select(Faculty).options(load_only(Faculty.name))
    res = session.scalars(stmt)#.all()
    for fac in res:
        print(fac.name, fac.id)
# Out:
# ПИНЖ 1
# ФИИТ 2
# МЕХТЕХ 3
# IT4 5
# Test5 6
# Test6 7
# Test1 8
# Test2 9
# IT31 4

# %%
### НО!!! запрос неперечисленной колонки

# %%
from sqlalchemy import select
from sqlalchemy.orm import load_only

with Session(engine) as session:
    stmt = select(Faculty).options(load_only(Faculty.name))
    res = session.scalars(stmt).all()
    for fac in res:
        print(fac)
# Out:
# Faculty(id=1, name='ПИНЖ', num=51)
# Faculty(id=2, name='ФИИТ', num=52)
# Faculty(id=3, name='МЕХТЕХ', num=53)
# Faculty(id=5, name='IT4', num=39)
# Faculty(id=6, name='Test5', num=905)
# Faculty(id=7, name='Test6', num=906)
# Faculty(id=8, name='Test1', num=901)
# Faculty(id=9, name='Test2', num=902)
# Faculty(id=4, name='IT31', num=38)

# %% [markdown]
# #### _and, _or

# %%
from sqlalchemy import and_, or_

session = Session(engine)

query = select(Course).where(
        and_(
            or_(Course.num == 12, Course.num == 11),
            Faculty.id == Course.faculty_id,
        )
    )
print(query)
print('-' * 50)

result = session.scalars(query).all()
print(result)
session.close()
# Out:
# SELECT course.id, course.num, course.faculty_id
# FROM course, faculty
# WHERE (course.num = :num_1 OR course.num = :num_2) AND faculty.id = course.faculty_id
# --------------------------------------------------
# [Course(id=2, num=12, faculty='ПИНЖ'), Course(id=1, num=11, faculty='ПИНЖ')]

# %% [markdown]
# #### scalars vs scalar

# %%
from sqlalchemy import and_, or_

session = Session(engine)

query = select(Course).where(
        and_(
            or_(Course.num == 12, Course.num == 11),
            Faculty.id == Course.faculty_id,
        )
    )
print(query)
print('-' * 50)

result = session.scalar(query)
print(result)
session.close()
# Out:
# SELECT course.id, course.num, course.faculty_id
# FROM course, faculty
# WHERE (course.num = :num_1 OR course.num = :num_2) AND faculty.id = course.faculty_id
# --------------------------------------------------
# Course(id=2, num=12, faculty='ПИНЖ')

# %% [markdown]
# ### Group by

# %%
from sqlalchemy import func

session = Session(engine)

query = (
    select(Faculty.name, func.count(Course.id).label("courses"))
    .join(Course)
    .group_by(Faculty.name)
    .having(func.count(Course.id) > 1)
)

print(query)

result = session.execute(query).all()
print(result)

session.close()
# Out:
# SELECT faculty.name, count(course.id) AS courses
# FROM faculty JOIN course ON faculty.id = course.faculty_id GROUP BY faculty.name
# HAVING count(course.id) > :count_1
# [('ФИИТ', 5), ('МЕХТЕХ', 5), ('ПИНЖ', 5)]

# %% [markdown]
# #### count

# %%
print(select(func.count()).select_from(Faculty))
# Out:
# SELECT count(*) AS count_1
# FROM faculty

# %% [markdown]
# ### Другой вар запроса

# %%
faculty_table = Faculty.__table__

stmt = select(faculty_table.c.id, faculty_table.c.name).where(faculty_table.c.name == "ФИИТ")
print(stmt)

session = Session(engine)

result = session.execute(stmt)
print(result.all())


session.close()
# Out:
# SELECT faculty.id, faculty.name
# FROM faculty
# WHERE faculty.name = :name_1
# [(2, 'ФИИТ')]

# %% [markdown]
# ## Insert

# %%
from sqlalchemy.orm import Session

with Session(engine) as session:
    f1 = Faculty(name="IT3", num=38)
    f2 = Faculty(name="IT4", num=39)
    session.add_all([f1, f2])
    session.commit()
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2116, in Connection._exec_insertmany_context(self, dialect, context)
#    2115     else:
# -> 2116         dialect.do_execute(
#    2117             cursor,
#    2118             sub_stmt,
#    2119             sub_params,
#    2120             context,
#    2121         )
#    2123 except BaseException as e:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# UniqueViolation: ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "faculty_num_uniq"
# DETAIL:  Ключ "(num)=(38)" уже существует.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[127], line 7
#       5 f2 = Faculty(name="IT4", num=39)
#       6 session.add_all([f1, f2])
# ----> 7 session.commit()
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:2017, in Session.commit(self)
#    2014 if trans is None:
#    2015     trans = self._autobegin_t()
# -> 2017 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:1302, in SessionTransaction.commit(self, _to_root)
#    1300 if self._state is not SessionTransactionState.PREPARED:
#    1301     with self._expect_state(SessionTransactionState.PREPARED):
# -> 1302         self._prepare_impl()
#    1304 if self._parent is None or self.nested:
#    1305     for conn, trans, should_commit, autoclose in set(
#    1306         self._connections.values()
#    1307     ):
#
# File <string>:2, in _prepare_impl(self)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:1277, in SessionTransaction._prepare_impl(self)
#    1275     if self.session._is_clean():
#    1276         break
# -> 1277     self.session.flush()
#    1278 else:
#    1279     raise exc.FlushError(
#    1280         "Over 100 subsequent flushes have occurred within "
#    1281         "session.commit() - is an after_flush() hook "
#    1282         "creating new objects?"
#    1283     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:4341, in Session.flush(self, objects)
#    4339 try:
#    4340     self._flushing = True
# -> 4341     self._flush(objects)
#    4342 finally:
#    4343     self._flushing = False
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:4476, in Session._flush(self, objects)
#    4473     transaction.commit()
#    4475 except:
# -> 4476     with util.safe_reraise():
#    4477         transaction.rollback(_capture_exception=True)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:4437, in Session._flush(self, objects)
#    4435 self._warn_on_events = True
#    4436 try:
# -> 4437     flush_context.execute()
#    4438 finally:
#    4439     self._warn_on_events = False
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\unitofwork.py:466, in UOWTransaction.execute(self)
#     464 else:
#     465     for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466         rec.execute(self)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      81     update = _collect_update_commands(
#      82         uowtransaction, table, states_to_update
#      83     )
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)
#      90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)
#     119     ),
#     120 )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\persistence.py:1143, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1140 if do_executemany:
#    1141     multiparams = [rec[2] for rec in records]
# -> 1143     result = connection.execute(
#    1144         statement, multiparams, execution_options=execution_options
#    1145     )
#    1147     if use_orm_insert_stmt is not None:
#    1148         if return_result is None:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1844, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841 context.pre_exec()
#    1843 if context.execute_style is ExecuteStyle.INSERTMANYVALUES:
# -> 1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
#    1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2124, in Connection._exec_insertmany_context(self, dialect, context)
#    2116         dialect.do_execute(
#    2117             cursor,
#    2118             sub_stmt,
#    2119             sub_params,
#    2120             context,
#    2121         )
#    2123 except BaseException as e:
# -> 2124     self._handle_dbapi_exception(
#    2125         e,
#    2126         sql_util._long_statement(sub_stmt),
#    2127         sub_params,
#    2128         cursor,
#    2129         context,
#    2130         is_sub_exec=True,
#    2131     )
#    2133 if engine_events:
#    2134     self.dispatch.after_cursor_execute(
#    2135         self,
#    2136         cursor,
#    (...)
#    2140         context.executemany,
#    2141     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2353, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2351 elif should_wrap:
#    2352     assert sqlalchemy_exception is not None
# -> 2353     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2354 else:
#    2355     assert exc_info[1] is not None
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2116, in Connection._exec_insertmany_context(self, dialect, context)
#    2114             break
#    2115     else:
# -> 2116         dialect.do_execute(
#    2117             cursor,
#    2118             sub_stmt,
#    2119             sub_params,
#    2120             context,
#    2121         )
#    2123 except BaseException as e:
#    2124     self._handle_dbapi_exception(
#    2125         e,
#    2126         sql_util._long_statement(sub_stmt),
#    (...)
#    2130         is_sub_exec=True,
#    2131     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# IntegrityError: (psycopg2.errors.UniqueViolation) ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "faculty_num_uniq"
# DETAIL:  Ключ "(num)=(38)" уже существует.
#
# [SQL: INSERT INTO faculty (name, num) SELECT p0::VARCHAR, p1::INTEGER FROM (VALUES (%(name__0)s, %(num__0)s, 0), (%(name__1)s, %(num__1)s, 1)) AS imp_sen(p0, p1, sen_counter) ORDER BY sen_counter RETURNING faculty.id, faculty.id AS id__1]
# [parameters: {'name__0': 'IT3', 'num__0': 38, 'name__1': 'IT4', 'num__1': 39}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
with Session(engine) as session:
    stmt = select(Faculty)
    for fac in session.scalars(stmt):
        print(fac)

# %% [markdown]
# ### Bulk Insert

# %%
from sqlalchemy import insert

with Session(engine) as session:
    result = session.execute(
        insert(Faculty),
        [
            {"name": "Test5", "num": 905},
            {"name": "Test6", "num": 906},
        ],
    )
    session.commit()
    # for i in result:
    #     print(i)

# %% [markdown]
# #### Returning

# %%
from sqlalchemy import insert

with Session(engine) as session:
    result = session.execute(
        insert(Faculty).returning(Faculty),
        [
            {"name": "Test1", "num": 901},
            {"name": "Test2", "num": 902},
        ],
    )
    session.commit()
    for i in result:
        print(i)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2116, in Connection._exec_insertmany_context(self, dialect, context)
#    2115     else:
# -> 2116         dialect.do_execute(
#    2117             cursor,
#    2118             sub_stmt,
#    2119             sub_params,
#    2120             context,
#    2121         )
#    2123 except BaseException as e:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# UniqueViolation: ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "faculty_num_uniq"
# DETAIL:  Ключ "(num)=(901)" уже существует.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[132], line 4
#       1 from sqlalchemy import insert
#       3 with Session(engine) as session:
# ----> 4     result = session.execute(
#       5         insert(Faculty).returning(Faculty),
#       6         [
#       7             {"name": "Test1", "num": 901},
#       8             {"name": "Test2", "num": 902},
#       9         ],
#      10     )
#      11     session.commit()
#      12     for i in result:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:2351, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2290 def execute(
#    2291     self,
#    2292     statement: Executable,
#    (...)
#    2298     _add_event: Optional[Any] = None,
#    2299 ) -> Result[Any]:
#    2300     r"""Execute a SQL expression construct.
#    2301
#    2302     Returns a :class:`_engine.Result` object representing
#    (...)
#    2349
#    2350     """
# -> 2351     return self._execute_internal(
#    2352         statement,
#    2353         params,
#    2354         execution_options=execution_options,
#    2355         bind_arguments=bind_arguments,
#    2356         _parent_execute_state=_parent_execute_state,
#    2357         _add_event=_add_event,
#    2358     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:2236, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2231     return conn.scalar(
#    2232         statement, params or {}, execution_options=execution_options
#    2233     )
#    2235 if compile_state_cls:
# -> 2236     result: Result[Any] = compile_state_cls.orm_execute_statement(
#    2237         self,
#    2238         statement,
#    2239         params or {},
#    2240         execution_options,
#    2241         bind_arguments,
#    2242         conn,
#    2243     )
#    2244 else:
#    2245     result = conn.execute(
#    2246         statement, params or {}, execution_options=execution_options
#    2247     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\bulk_persistence.py:1269, in BulkORMInsert.orm_execute_statement(cls, session, statement, params, execution_options, bind_arguments, conn)
#    1267     assert mapper is not None
#    1268     assert session._transaction is not None
# -> 1269     result = _bulk_insert(
#    1270         mapper,
#    1271         cast(
#    1272             "Iterable[Dict[str, Any]]",
#    1273             [params] if isinstance(params, dict) else params,
#    1274         ),
#    1275         session._transaction,
#    1276         isstates=False,
#    1277         return_defaults=insert_options._return_defaults,
#    1278         render_nulls=insert_options._render_nulls,
#    1279         use_orm_insert_stmt=statement,
#    1280         execution_options=execution_options,
#    1281     )
#    1282 elif insert_options._dml_strategy == "orm":
#    1283     result = conn.execute(
#    1284         statement, params or {}, execution_options=execution_options
#    1285     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\bulk_persistence.py:200, in _bulk_insert(mapper, mappings, session_transaction, isstates, return_defaults, render_nulls, use_orm_insert_stmt, execution_options)
#     160 extra_bp_names = (
#     161     [
#     162         b.key
#    (...)
#     167     else ()
#     168 )
#     170 records = (
#     171     (
#     172         None,
#    (...)
#     197     )
#     198 )
# --> 200 result = persistence._emit_insert_statements(
#     201     base_mapper,
#     202     None,
#     203     super_mapper,
#     204     table,
#     205     records,
#     206     bookkeeping=bookkeeping,
#     207     use_orm_insert_stmt=use_orm_insert_stmt,
#     208     execution_options=execution_options,
#     209 )
#     210 if use_orm_insert_stmt is not None:
#     211     if not use_orm_insert_stmt._returning or return_result is None:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\persistence.py:1143, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1140 if do_executemany:
#    1141     multiparams = [rec[2] for rec in records]
# -> 1143     result = connection.execute(
#    1144         statement, multiparams, execution_options=execution_options
#    1145     )
#    1147     if use_orm_insert_stmt is not None:
#    1148         if return_result is None:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1844, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841 context.pre_exec()
#    1843 if context.execute_style is ExecuteStyle.INSERTMANYVALUES:
# -> 1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
#    1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2124, in Connection._exec_insertmany_context(self, dialect, context)
#    2116         dialect.do_execute(
#    2117             cursor,
#    2118             sub_stmt,
#    2119             sub_params,
#    2120             context,
#    2121         )
#    2123 except BaseException as e:
# -> 2124     self._handle_dbapi_exception(
#    2125         e,
#    2126         sql_util._long_statement(sub_stmt),
#    2127         sub_params,
#    2128         cursor,
#    2129         context,
#    2130         is_sub_exec=True,
#    2131     )
#    2133 if engine_events:
#    2134     self.dispatch.after_cursor_execute(
#    2135         self,
#    2136         cursor,
#    (...)
#    2140         context.executemany,
#    2141     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2353, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2351 elif should_wrap:
#    2352     assert sqlalchemy_exception is not None
# -> 2353     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2354 else:
#    2355     assert exc_info[1] is not None
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2116, in Connection._exec_insertmany_context(self, dialect, context)
#    2114             break
#    2115     else:
# -> 2116         dialect.do_execute(
#    2117             cursor,
#    2118             sub_stmt,
#    2119             sub_params,
#    2120             context,
#    2121         )
#    2123 except BaseException as e:
#    2124     self._handle_dbapi_exception(
#    2125         e,
#    2126         sql_util._long_statement(sub_stmt),
#    (...)
#    2130         is_sub_exec=True,
#    2131     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# IntegrityError: (psycopg2.errors.UniqueViolation) ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "faculty_num_uniq"
# DETAIL:  Ключ "(num)=(901)" уже существует.
#
# [SQL: INSERT INTO faculty (name, num) VALUES (%(name__0)s, %(num__0)s), (%(name__1)s, %(num__1)s) RETURNING faculty.id, faculty.name, faculty.num]
# [parameters: {'name__0': 'Test1', 'num__0': 901, 'name__1': 'Test2', 'num__1': 902}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %% [markdown]
# ## Update

# %% [markdown]
# ### update one

# %%
session = Session(engine)

query = select(Faculty).where(Faculty.num == 38)
fac = session.scalars(query).one()
print(fac)

fac.name = 'IT31'
session.commit()

fac = session.scalars(query).one()
print(fac)

session.close()
# Out:
# Faculty(id=4, name='IT31', num=38)
# Faculty(id=4, name='IT31', num=38)

# %%
from sqlalchemy import update

stmt = (
    update(user_table)
    .where(user_table.c.name == "patrick")
    .values(fullname="Patrick the Star")
)
print(stmt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[138], line 4
#       1 from sqlalchemy import update
#       3 stmt = (
# ----> 4     update(user_table)
#       5     .where(user_table.c.name == "patrick")
#       6     .values(fullname="Patrick the Star")
#       7 )
#       8 print(stmt)
#
# NameError: name 'user_table' is not defined

# %%
Faculty.__table__
# Out:
# Table('faculty', MetaData(), Column('id', Integer(), table=<faculty>, primary_key=True, nullable=False), Column('name', String(length=30), table=<faculty>, nullable=False), Column('num', Integer(), table=<faculty>, nullable=False), schema=None)

# %% [markdown]
# ### update related

# %%
with Session(engine) as session:
    query = select(Faculty).where(Faculty.num == 38)
    fac = session.scalars(query).one()
    fac.courses.append(Course(num=389))
    session.commit()
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# UniqueViolation: ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "course_num_uniq"
# DETAIL:  Ключ "(num)=(389)" уже существует.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[143], line 5
#       3 fac = session.scalars(query).one()
#       4 fac.courses.append(Course(num=389))
# ----> 5 session.commit()
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:2017, in Session.commit(self)
#    2014 if trans is None:
#    2015     trans = self._autobegin_t()
# -> 2017 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:1302, in SessionTransaction.commit(self, _to_root)
#    1300 if self._state is not SessionTransactionState.PREPARED:
#    1301     with self._expect_state(SessionTransactionState.PREPARED):
# -> 1302         self._prepare_impl()
#    1304 if self._parent is None or self.nested:
#    1305     for conn, trans, should_commit, autoclose in set(
#    1306         self._connections.values()
#    1307     ):
#
# File <string>:2, in _prepare_impl(self)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:1277, in SessionTransaction._prepare_impl(self)
#    1275     if self.session._is_clean():
#    1276         break
# -> 1277     self.session.flush()
#    1278 else:
#    1279     raise exc.FlushError(
#    1280         "Over 100 subsequent flushes have occurred within "
#    1281         "session.commit() - is an after_flush() hook "
#    1282         "creating new objects?"
#    1283     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:4341, in Session.flush(self, objects)
#    4339 try:
#    4340     self._flushing = True
# -> 4341     self._flush(objects)
#    4342 finally:
#    4343     self._flushing = False
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:4476, in Session._flush(self, objects)
#    4473     transaction.commit()
#    4475 except:
# -> 4476     with util.safe_reraise():
#    4477         transaction.rollback(_capture_exception=True)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:4437, in Session._flush(self, objects)
#    4435 self._warn_on_events = True
#    4436 try:
# -> 4437     flush_context.execute()
#    4438 finally:
#    4439     self._warn_on_events = False
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\unitofwork.py:466, in UOWTransaction.execute(self)
#     464 else:
#     465     for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466         rec.execute(self)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      81     update = _collect_update_commands(
#      82         uowtransaction, table, states_to_update
#      83     )
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)
#      90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)
#     119     ),
#     120 )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\persistence.py:1233, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1227     result = connection.execute(
#    1228         statement.values(value_params),
#    1229         params,
#    1230         execution_options=execution_options,
#    1231     )
#    1232 else:
# -> 1233     result = connection.execute(
#    1234         statement,
#    1235         params,
#    1236         execution_options=execution_options,
#    1237     )
#    1239 primary_key = result.inserted_primary_key
#    1240 if primary_key is None:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2353, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2351 elif should_wrap:
#    2352     assert sqlalchemy_exception is not None
# -> 2353     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2354 else:
#    2355     assert exc_info[1] is not None
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)
#    1978         context.executemany,
#    1979     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# IntegrityError: (psycopg2.errors.UniqueViolation) ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "course_num_uniq"
# DETAIL:  Ключ "(num)=(389)" уже существует.
#
# [SQL: INSERT INTO course (num, faculty_id) VALUES (%(num)s, %(faculty_id)s) RETURNING course.id]
# [parameters: {'num': 389, 'faculty_id': 4}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
with Session(engine) as session:
    stmt = (
        select(Course)
            .join(Course.faculty)
            .where(Faculty.num == 38)
        )
    result = session.scalars(stmt).all()
    print(result)
# Out:
# [Course(id=16, num=389, faculty='IT31')]

# %% [markdown]
# ### Bulk Update

# %% [markdown]
# ## Deletion

# %%
with Session(engine) as session:
    c1 = session.get(Course, 25)
    session.delete(c1)
    session.commit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:3523, in Session.delete(self, instance)
#    3522 try:
# -> 3523     state = attributes.instance_state(instance)
#    3524 except exc.NO_STATE as err:
#
# AttributeError: 'NoneType' object has no attribute '_sa_instance_state'
#
# The above exception was the direct cause of the following exception:
#
# UnmappedInstanceError                     Traceback (most recent call last)
# Cell In[150], line 3
#       1 with Session(engine) as session:
#       2     c1 = session.get(Course, 25)
# ----> 3     session.delete(c1)
#       4     session.commit()
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:3525, in Session.delete(self, instance)
#    3523     state = attributes.instance_state(instance)
#    3524 except exc.NO_STATE as err:
# -> 3525     raise exc.UnmappedInstanceError(instance) from err
#    3527 self._delete_impl(state, instance, head=True)
#
# UnmappedInstanceError: Class 'builtins.NoneType' is not mapped

# %% [markdown]
# #### Bulk delete

# %%
with Session(engine) as session:
    stmt = Faculty.__table__.delete().where(Faculty.id > 10)
    session.execute(stmt)
    session.commit()

# %% [markdown]
# 1. Сделать ORM таблички к остальным таблицам (Group, Student, Mark, Teacher, etc.)
# 2. Проверить правильность созданных классов с помощью ORM запросов select, используя
# https://docs.sqlalchemy.org/en/20/orm/queryguide/select.html
#     1) all(), one(), first(), one_or_none()
#     2) where()
#     3) order_by, desc
#     4) limit, offset, count
#     5) where, and_, or_
#     6) count, distinct
#     7) join, group_dy
#     8) exists, см. https://docs.sqlalchemy.org/en/20/core/selectable.html#sqlalchemy.sql.expression.exists
#     9) like, not like (подсмотреть в примере https://docs.sqlalchemy.org/en/20/tutorial/data_select.html#orm-entity-subqueries-ctes)
# 3. вывести 1-2 результатов таких запросов как датафрейм
# 4. Выбрать студентов одной группы, и тем, у кого нет оценок, добавить рандомные оценки от 2 до 5 по одному предмету за одну дату.
# см. https://docs.sqlalchemy.org/en/20/orm/queryguide/dml.html#orm-queryguide-bulk-update
# 5. Выбрать оценки "2", добавленные в п.4, и исправить их на рандомно "3" или "4".
# 6. Удалить 2 рандомные оценки из п.4

# %%
from typing import List, Optional
from sqlalchemy import ForeignKey, String
from sqlalchemy.orm import DeclarativeBase, Mapped, Session, mapped_column, relationship


class Base(DeclarativeBase):
    pass


class Faculty(Base):
    __tablename__ = "faculty"

    id: Mapped[int] = mapped_column(primary_key=True)
    name: Mapped[str] = mapped_column(String(30))
    num: Mapped[int]

    courses: Mapped[List["Course"]] = relationship(back_populates="faculty", cascade="all, delete-orphan")

    def __repr__(self) -> str:
        return f"Faculty(id={self.id!r}, name={self.name!r}, num={self.num!r})"


class Course(Base):
    __tablename__ = "course"
    id: Mapped[int] = mapped_column(primary_key=True)
    num: Mapped[int]

    faculty_id: Mapped[int] = mapped_column(ForeignKey("faculty.id"))
    faculty: Mapped["Faculty"] = relationship(back_populates="courses")

    groups: Mapped[List["Group"]] = relationship(back_populates="course", cascade="all, delete-orphan")
    def __repr__(self) -> str:
        return f"Course(id={self.id!r}, num={self.num!r}, faculty={self.faculty.name!r})"

class Group(Base):
    __tablename__ = "groups"
    id: Mapped[int] = mapped_column(primary_key=True)
    num: Mapped[int]
    commercial: Mapped[bool]
    course_id: Mapped[int] = mapped_column(ForeignKey("course.id"))
    course: Mapped["Course"] = relationship(back_populates="groups")

    student: Mapped[List["Student"]] = relationship(back_populates="groups", cascade="all, delete-orphan")
    def __repr__(self) -> str:
        return f"Group(id={self.id!r}, num={self.num!r}, course={self.course.num!r}, commercial={self.commercial!r})"

class Student(Base):
    __tablename__ = "student"
    id: Mapped[int] = mapped_column(primary_key=True)
    first_name: Mapped[str] = mapped_column(String(30))
    last_name: Mapped[str] = mapped_column(String(30))
    middle_name: Mapped[str] = mapped_column(String(30))
    date_of_birth: Mapped[str] = mapped_column(String(30))
    inn: Mapped[int]
    gender: Mapped[str] = mapped_column(String(30))
    
    groups_id: Mapped[int] = mapped_column(ForeignKey("groups.id"))
    groups: Mapped["Group"] = relationship(back_populates="student")

    marks: Mapped[List["Marks"]] = relationship(back_populates="student", cascade="all, delete-orphan")
    def __repr__(self) -> str:
        return f"Student(id={self.id!r}, name={self.first_name!r} {self.middle_name!r} {self.last_name!r}, group={self.groups.num!r}, date_of_birth={self.date_of_birth!r}, inn={self.inn!r}, gender={self.gender!r})"

class Subject(Base):
    __tablename__ = "subjects"
    id: Mapped[int] = mapped_column(primary_key=True)
    subject: Mapped[str] = mapped_column(String(30))
    
    marks: Mapped[List["Marks"]] = relationship(back_populates="subjects", cascade="all, delete-orphan")
    def __repr__(self) -> str:
        return f"Subject(id={self.id!r}, name={self.subject!r}"

class Marks(Base):
    __tablename__ = "marks"
    id: Mapped[int] = mapped_column(primary_key=True)
    mark: Mapped[int]
    subject_id: Mapped[int] = mapped_column(ForeignKey("subjects.id"))
    subjects: Mapped["Subject"] = relationship(back_populates="marks")
    student_id: Mapped[int] = mapped_column(ForeignKey("student.id"))
    student: Mapped["Student"] = relationship(back_populates="marks")
    def __repr__(self) -> str:
        return f"Mark(id={self.id!r}, mark={self.mark!r}, subject={self.subjects.subject}, student={self.student.first_name!r} {self.student.middle_name!r} {self.student.last_name!r}"

# %%
from sqlalchemy import create_engine

DB_HOST = 'localhost'
DB_PORT = 5432
DB_NAME = 'students'
DB_USER = 'postgres'
DB_PASSWORD = 'root'

engine = create_engine(f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}")

# %%
from sqlalchemy.orm import Session
from sqlalchemy import select

with Session(engine) as session:
    stmt = select(Faculty)
    for fac in session.scalars(stmt):
        print(fac)
# Out:
# Faculty(id=1, name='ПИНЖ', num=51)
# Faculty(id=2, name='ФИИТ', num=52)
# Faculty(id=3, name='МЕХТЕХ', num=53)
# Faculty(id=5, name='IT4', num=39)
# Faculty(id=6, name='Test5', num=905)
# Faculty(id=7, name='Test6', num=906)
# Faculty(id=8, name='Test1', num=901)
# Faculty(id=9, name='Test2', num=902)
# Faculty(id=4, name='IT31', num=38)

# %%
from sqlalchemy import select

stmt = select(Faculty)
session.execute(stmt).all()
# Out:
# [(Faculty(id=1, name='ПИНЖ', num=51),),
#  (Faculty(id=2, name='ФИИТ', num=52),),
#  (Faculty(id=3, name='МЕХТЕХ', num=53),),
#  (Faculty(id=5, name='IT4', num=39),),
#  (Faculty(id=6, name='Test5', num=905),),
#  (Faculty(id=7, name='Test6', num=906),),
#  (Faculty(id=8, name='Test1', num=901),),
#  (Faculty(id=9, name='Test2', num=902),),
#  (Faculty(id=4, name='IT31', num=38),)]

# %%
stmt = select(Student)
session.execute(stmt).all()
# Out:
# [(Student(id=4, name='Иван' 'Иванович' 'Иванов', group=111, date_of_birth=datetime.date(2006, 2, 2), inn=525677889912, gender='М'),),
#  (Student(id=5, name='Никита' 'Олегович' 'Никитин', group=111, date_of_birth=datetime.date(2006, 3, 3), inn=525677889913, gender='М'),),
#  (Student(id=6, name='Марина' 'Ивановна' 'Маринина', group=111, date_of_birth=datetime.date(2006, 3, 4), inn=525677889914, gender='Ж'),),
#  (Student(id=7, name='Жанна' 'Алексеевна' 'Сергеева', group=111, date_of_birth=datetime.date(2006, 1, 1), inn=525677889915, gender='Ж'),),
#  (Student(id=8, name='Кирилл' 'Кириллович' 'Сергеев', group=112, date_of_birth=datetime.date(2006, 11, 5), inn=525677889916, gender='М'),),
#  (Student(id=9, name='Федя' 'Потапович' 'Колбаскин', group=112, date_of_birth=datetime.date(2006, 10, 10), inn=525677889917, gender='М'),),
#  (Student(id=10, name='Ольга' 'Петровна' 'Петрова', group=112, date_of_birth=datetime.date(2006, 5, 6), inn=525677889918, gender='Ж'),),
#  (Student(id=11, name='Валя' 'Патрикеевна' 'Изенштейн', group=112, date_of_birth=datetime.date(2006, 12, 3), inn=525677889919, gender='Ж'),),
#  (Student(id=12, name='Дмитрий' 'Осипович' 'Оз', group=112, date_of_birth=datetime.date(2006, 6, 7), inn=525677889920, gender='М'),),
#  (Student(id=13, name='Остап' 'Изяславович' 'Остапов', group=113, date_of_birth=datetime.date(2006, 2, 22), inn=525677889921, gender='М'),),
#  (Student(id=14, name='Гена' 'Герасимович' 'Офиногенов', group=113, date_of_birth=datetime.date(2006, 7, 30), inn=525677889923, gender='М'),),
#  (Student(id=15, name='Лена' 'Валерьевна' 'Копытова', group=113, date_of_birth=datetime.date(2006, 8, 9), inn=525677889924, gender='Ж'),),
#  (Student(id=16, name='Петр' 'Иванович' 'Обломов', group=113, date_of_birth=datetime.date(2006, 1, 16), inn=525677889925, gender='М'),),
#  (Student(id=17, name='Зина' 'Леопольдовна' 'Турбина', group=113, date_of_birth=datetime.date(2006, 9, 1), inn=525677889926, gender='Ж'),),
#  (Student(id=18, name='Аскольд' 'Тигранович' 'Распашный', group=121, date_of_birth=datetime.date(2005, 1, 1), inn=525677889927, gender='М'),),
#  (Student(id=19, name='Петр' 'Алексеевич' 'Первый', group=121, date_of_birth=datetime.date(2005, 5, 5), inn=525677889928, gender='М'),),
#  (Student(id=20, name='Данила' 'Кириллович' 'Мазила', group=121, date_of_birth=datetime.date(2005, 12, 11), inn=525677889929, gender='М'),),
#  (Student(id=21, name='Камила' 'Абдулкадеровна' 'Забила', group=121, date_of_birth=datetime.date(2005, 7, 2), inn=525677889930, gender='Ж'),),
#  (Student(id=22, name='Валентин' 'Гавриилович' 'Амуров', group=121, date_of_birth=datetime.date(2005, 4, 9), inn=525677889931, gender='М'),),
#  (Student(id=23, name='Хасан' 'Саидович' 'Аскеров', group=122, date_of_birth=datetime.date(2005, 1, 22), inn=525677889932, gender='М'),),
#  (Student(id=24, name='Ашот' 'Раисович' 'Нетот', group=122, date_of_birth=datetime.date(2005, 11, 11), inn=525677889933, gender='М'),),
#  (Student(id=25, name='Даша' 'Сергеевна' 'Неваляшкина', group=122, date_of_birth=datetime.date(2006, 12, 12), inn=525677889934, gender='Ж'),),
#  (Student(id=26, name='Элла' 'Назимовна' 'Накипелло', group=122, date_of_birth=datetime.date(2005, 9, 9), inn=525677889935, gender='Ж'),),
#  (Student(id=27, name='Каштан' 'Рамбутанович' 'Баклажан', group=122, date_of_birth=datetime.date(2005, 6, 26), inn=525677889936, gender='М'),),
#  (Student(id=28, name='Джон' '' 'Смит', group=123, date_of_birth=datetime.date(2005, 2, 23), inn=525677889937, gender='М'),),
#  (Student(id=29, name='Генрих' 'Азимутович' 'Штойц', group=123, date_of_birth=datetime.date(2005, 8, 6), inn=525677889938, gender='М'),),
#  (Student(id=30, name='Арам' 'Арамович' 'Бабаян', group=123, date_of_birth=datetime.date(2005, 5, 1), inn=525677889939, gender='М'),),
#  (Student(id=31, name='Ксюша' 'Ксилофоновна' 'Изплюша', group=123, date_of_birth=datetime.date(2005, 2, 11), inn=525677889940, gender='Ж'),),
#  (Student(id=32, name='Анна' 'Алексеевна' 'Одинцова', group=123, date_of_birth=datetime.date(2005, 10, 21), inn=525677889941, gender='Ж'),),
#  (Student(id=33, name='Алина' 'Александровна' 'Редькина', group=111, date_of_birth=datetime.date(2005, 5, 14), inn=52544444444, gender='Ж'),),
#  (Student(id=3, name='Петр' 'Петрович' 'Петров', group=111, date_of_birth=datetime.date(2005, 1, 3), inn=525677889911, gender='М'),),
#  (Student(id=38, name='Анна' 'Дмитриевна' 'Алексеева', group=111, date_of_birth=datetime.date(2006, 5, 1), inn=525677889999, gender=None),),
#  (Student(id=39, name='Сергей' 'Михайлович' 'Сергеев', group=111, date_of_birth=datetime.date(2006, 6, 2), inn=525677889922, gender=None),),
#  (Student(id=40, name='Ольга' 'Станиславовна' 'Ольгина', group=111, date_of_birth=datetime.date(2006, 7, 3), inn=525677889992, gender=None),),
#  (Student(id=41, name='Дмитрий' 'Алексеевич' 'Дмитриев', group=111, date_of_birth=datetime.date(2006, 8, 4), inn=525677889993, gender=None),),
#  (Student(id=42, name='Екатерина' 'Сергеевна' 'Петрова', group=111, date_of_birth=datetime.date(2006, 9, 1), inn=525677889988, gender=None),)]

# %%
session.execute(stmt).first()
# Out:
# (Student(id=4, name='Иван' 'Иванович' 'Иванов', group=111, date_of_birth=datetime.date(2006, 2, 2), inn=525677889912, gender='М'),)

# %%
session = Session(engine)

stmt = select(Student).where(Student.id == 32)
f = session.scalars(stmt).one()
print(f)
# Out:
# Student(id=32, name='Анна' 'Алексеевна' 'Одинцова', group=123, date_of_birth=datetime.date(2005, 10, 21), inn=525677889941, gender='Ж')

# %%
session = Session(engine)

stmt = select(Student).where(Student.id == 37)
fac = session.scalars(stmt).one_or_none()
print(fac)
# Out:
# None

# %%
stmt = select(Student).where(Student.id == 11)
session.execute(stmt).all()
# Out:
# [(Student(id=11, name='Валя' 'Патрикеевна' 'Изенштейн', group=112, date_of_birth=datetime.date(2006, 12, 3), inn=525677889919, gender='Ж'),)]

# %%
stmt = select(Student).where(Student.groups_id == 1).order_by(Student.first_name)
session.execute(stmt).all()
# Out:
# [(Student(id=33, name='Алина' 'Александровна' 'Редькина', group=111, date_of_birth=datetime.date(2005, 5, 14), inn=52544444444, gender='Ж'),),
#  (Student(id=38, name='Анна' 'Дмитриевна' 'Алексеева', group=111, date_of_birth=datetime.date(2006, 5, 1), inn=525677889999, gender=None),),
#  (Student(id=41, name='Дмитрий' 'Алексеевич' 'Дмитриев', group=111, date_of_birth=datetime.date(2006, 8, 4), inn=525677889993, gender=None),),
#  (Student(id=42, name='Екатерина' 'Сергеевна' 'Петрова', group=111, date_of_birth=datetime.date(2006, 9, 1), inn=525677889988, gender=None),),
#  (Student(id=7, name='Жанна' 'Алексеевна' 'Сергеева', group=111, date_of_birth=datetime.date(2006, 1, 1), inn=525677889915, gender='Ж'),),
#  (Student(id=4, name='Иван' 'Иванович' 'Иванов', group=111, date_of_birth=datetime.date(2006, 2, 2), inn=525677889912, gender='М'),),
#  (Student(id=6, name='Марина' 'Ивановна' 'Маринина', group=111, date_of_birth=datetime.date(2006, 3, 4), inn=525677889914, gender='Ж'),),
#  (Student(id=5, name='Никита' 'Олегович' 'Никитин', group=111, date_of_birth=datetime.date(2006, 3, 3), inn=525677889913, gender='М'),),
#  (Student(id=40, name='Ольга' 'Станиславовна' 'Ольгина', group=111, date_of_birth=datetime.date(2006, 7, 3), inn=525677889992, gender=None),),
#  (Student(id=3, name='Петр' 'Петрович' 'Петров', group=111, date_of_birth=datetime.date(2005, 1, 3), inn=525677889911, gender='М'),),
#  (Student(id=39, name='Сергей' 'Михайлович' 'Сергеев', group=111, date_of_birth=datetime.date(2006, 6, 2), inn=525677889922, gender=None),)]

# %%
from sqlalchemy import desc

stmt = select(Student).where(Student.groups_id == 2).order_by(desc(Student.first_name))
session.execute(stmt).all()
# Out:
# [(Student(id=9, name='Федя' 'Потапович' 'Колбаскин', group=112, date_of_birth=datetime.date(2006, 10, 10), inn=525677889917, gender='М'),),
#  (Student(id=10, name='Ольга' 'Петровна' 'Петрова', group=112, date_of_birth=datetime.date(2006, 5, 6), inn=525677889918, gender='Ж'),),
#  (Student(id=8, name='Кирилл' 'Кириллович' 'Сергеев', group=112, date_of_birth=datetime.date(2006, 11, 5), inn=525677889916, gender='М'),),
#  (Student(id=12, name='Дмитрий' 'Осипович' 'Оз', group=112, date_of_birth=datetime.date(2006, 6, 7), inn=525677889920, gender='М'),),
#  (Student(id=11, name='Валя' 'Патрикеевна' 'Изенштейн', group=112, date_of_birth=datetime.date(2006, 12, 3), inn=525677889919, gender='Ж'),)]

# %%
stmt = select(Student).where(Student.groups_id == 2).order_by(Student.first_name).limit(2)
session.execute(stmt).all()
# Out:
# [(Student(id=11, name='Валя' 'Патрикеевна' 'Изенштейн', group=112, date_of_birth=datetime.date(2006, 12, 3), inn=525677889919, gender='Ж'),),
#  (Student(id=12, name='Дмитрий' 'Осипович' 'Оз', group=112, date_of_birth=datetime.date(2006, 6, 7), inn=525677889920, gender='М'),)]

# %%
stmt = select(Student).where(Student.groups_id == 2).order_by(Student.first_name).offset(3)
session.execute(stmt).all()
# Out:
# [(Student(id=10, name='Ольга' 'Петровна' 'Петрова', group=112, date_of_birth=datetime.date(2006, 5, 6), inn=525677889918, gender='Ж'),),
#  (Student(id=9, name='Федя' 'Потапович' 'Колбаскин', group=112, date_of_birth=datetime.date(2006, 10, 10), inn=525677889917, gender='М'),)]

# %%
from sqlalchemy import func

stmt = select(func.count()).where(Student.groups_id == 2)
session.execute(stmt).all()
# Out:
# [(5,)]

# %%
from sqlalchemy import and_, or_

session = Session(engine)

stmt = select(Student).where(
        and_(
            or_(Student.groups_id == 1, Student.groups_id == 2),
            Student.gender == 'М',
        )
    )
session.execute(stmt).all()
# Out:
# [(Student(id=4, name='Иван' 'Иванович' 'Иванов', group=111, date_of_birth=datetime.date(2006, 2, 2), inn=525677889912, gender='М'),),
#  (Student(id=5, name='Никита' 'Олегович' 'Никитин', group=111, date_of_birth=datetime.date(2006, 3, 3), inn=525677889913, gender='М'),),
#  (Student(id=8, name='Кирилл' 'Кириллович' 'Сергеев', group=112, date_of_birth=datetime.date(2006, 11, 5), inn=525677889916, gender='М'),),
#  (Student(id=9, name='Федя' 'Потапович' 'Колбаскин', group=112, date_of_birth=datetime.date(2006, 10, 10), inn=525677889917, gender='М'),),
#  (Student(id=12, name='Дмитрий' 'Осипович' 'Оз', group=112, date_of_birth=datetime.date(2006, 6, 7), inn=525677889920, gender='М'),),
#  (Student(id=3, name='Петр' 'Петрович' 'Петров', group=111, date_of_birth=datetime.date(2005, 1, 3), inn=525677889911, gender='М'),)]

# %%
from sqlalchemy import select, func
session = Session(engine)
stmt = select(func.distinct(Student.first_name)).where(Student.groups_id == 2)
session.execute(stmt).all()
# Out:
# [('Федя',), ('Кирилл',), ('Дмитрий',), ('Валя',), ('Ольга',)]

# %%
from sqlalchemy import select, func
session = Session(engine)

stmt = (
        select(Student)
            .join(Student.groups)
            .where(Student.id <= 20)
            .group_by(Student.id)
        )
session.execute(stmt).all()
# Out:
# [(Student(id=11, name='Валя' 'Патрикеевна' 'Изенштейн', group=112, date_of_birth=datetime.date(2006, 12, 3), inn=525677889919, gender='Ж'),),
#  (Student(id=8, name='Кирилл' 'Кириллович' 'Сергеев', group=112, date_of_birth=datetime.date(2006, 11, 5), inn=525677889916, gender='М'),),
#  (Student(id=19, name='Петр' 'Алексеевич' 'Первый', group=121, date_of_birth=datetime.date(2005, 5, 5), inn=525677889928, gender='М'),),
#  (Student(id=4, name='Иван' 'Иванович' 'Иванов', group=111, date_of_birth=datetime.date(2006, 2, 2), inn=525677889912, gender='М'),),
#  (Student(id=14, name='Гена' 'Герасимович' 'Офиногенов', group=113, date_of_birth=datetime.date(2006, 7, 30), inn=525677889923, gender='М'),),
#  (Student(id=3, name='Петр' 'Петрович' 'Петров', group=111, date_of_birth=datetime.date(2005, 1, 3), inn=525677889911, gender='М'),),
#  (Student(id=17, name='Зина' 'Леопольдовна' 'Турбина', group=113, date_of_birth=datetime.date(2006, 9, 1), inn=525677889926, gender='Ж'),),
#  (Student(id=20, name='Данила' 'Кириллович' 'Мазила', group=121, date_of_birth=datetime.date(2005, 12, 11), inn=525677889929, gender='М'),),
#  (Student(id=13, name='Остап' 'Изяславович' 'Остапов', group=113, date_of_birth=datetime.date(2006, 2, 22), inn=525677889921, gender='М'),),
#  (Student(id=10, name='Ольга' 'Петровна' 'Петрова', group=112, date_of_birth=datetime.date(2006, 5, 6), inn=525677889918, gender='Ж'),),
#  (Student(id=9, name='Федя' 'Потапович' 'Колбаскин', group=112, date_of_birth=datetime.date(2006, 10, 10), inn=525677889917, gender='М'),),
#  (Student(id=7, name='Жанна' 'Алексеевна' 'Сергеева', group=111, date_of_birth=datetime.date(2006, 1, 1), inn=525677889915, gender='Ж'),),
#  (Student(id=5, name='Никита' 'Олегович' 'Никитин', group=111, date_of_birth=datetime.date(2006, 3, 3), inn=525677889913, gender='М'),),
#  (Student(id=18, name='Аскольд' 'Тигранович' 'Распашный', group=121, date_of_birth=datetime.date(2005, 1, 1), inn=525677889927, gender='М'),),
#  (Student(id=16, name='Петр' 'Иванович' 'Обломов', group=113, date_of_birth=datetime.date(2006, 1, 16), inn=525677889925, gender='М'),),
#  (Student(id=15, name='Лена' 'Валерьевна' 'Копытова', group=113, date_of_birth=datetime.date(2006, 8, 9), inn=525677889924, gender='Ж'),),
#  (Student(id=6, name='Марина' 'Ивановна' 'Маринина', group=111, date_of_birth=datetime.date(2006, 3, 4), inn=525677889914, gender='Ж'),),
#  (Student(id=12, name='Дмитрий' 'Осипович' 'Оз', group=112, date_of_birth=datetime.date(2006, 6, 7), inn=525677889920, gender='М'),)]

# %%
from sqlalchemy import exists
session = Session(engine)

students_with_groups = session.query(Student).filter(
    exists().where(Student.groups_id == Group.id)
).all()

students_with_groups
# Out:
# [Student(id=4, name='Иван' 'Иванович' 'Иванов', group=111, date_of_birth=datetime.date(2006, 2, 2), inn=525677889912, gender='М'),
#  Student(id=5, name='Никита' 'Олегович' 'Никитин', group=111, date_of_birth=datetime.date(2006, 3, 3), inn=525677889913, gender='М'),
#  Student(id=6, name='Марина' 'Ивановна' 'Маринина', group=111, date_of_birth=datetime.date(2006, 3, 4), inn=525677889914, gender='Ж'),
#  Student(id=7, name='Жанна' 'Алексеевна' 'Сергеева', group=111, date_of_birth=datetime.date(2006, 1, 1), inn=525677889915, gender='Ж'),
#  Student(id=8, name='Кирилл' 'Кириллович' 'Сергеев', group=112, date_of_birth=datetime.date(2006, 11, 5), inn=525677889916, gender='М'),
#  Student(id=9, name='Федя' 'Потапович' 'Колбаскин', group=112, date_of_birth=datetime.date(2006, 10, 10), inn=525677889917, gender='М'),
#  Student(id=10, name='Ольга' 'Петровна' 'Петрова', group=112, date_of_birth=datetime.date(2006, 5, 6), inn=525677889918, gender='Ж'),
#  Student(id=11, name='Валя' 'Патрикеевна' 'Изенштейн', group=112, date_of_birth=datetime.date(2006, 12, 3), inn=525677889919, gender='Ж'),
#  Student(id=12, name='Дмитрий' 'Осипович' 'Оз', group=112, date_of_birth=datetime.date(2006, 6, 7), inn=525677889920, gender='М'),
#  Student(id=13, name='Остап' 'Изяславович' 'Остапов', group=113, date_of_birth=datetime.date(2006, 2, 22), inn=525677889921, gender='М'),
#  Student(id=14, name='Гена' 'Герасимович' 'Офиногенов', group=113, date_of_birth=datetime.date(2006, 7, 30), inn=525677889923, gender='М'),
#  Student(id=15, name='Лена' 'Валерьевна' 'Копытова', group=113, date_of_birth=datetime.date(2006, 8, 9), inn=525677889924, gender='Ж'),
#  Student(id=16, name='Петр' 'Иванович' 'Обломов', group=113, date_of_birth=datetime.date(2006, 1, 16), inn=525677889925, gender='М'),
#  Student(id=17, name='Зина' 'Леопольдовна' 'Турбина', group=113, date_of_birth=datetime.date(2006, 9, 1), inn=525677889926, gender='Ж'),
#  Student(id=18, name='Аскольд' 'Тигранович' 'Распашный', group=121, date_of_birth=datetime.date(2005, 1, 1), inn=525677889927, gender='М'),
#  Student(id=19, name='Петр' 'Алексеевич' 'Первый', group=121, date_of_birth=datetime.date(2005, 5, 5), inn=525677889928, gender='М'),
#  Student(id=20, name='Данила' 'Кириллович' 'Мазила', group=121, date_of_birth=datetime.date(2005, 12, 11), inn=525677889929, gender='М'),
#  Student(id=21, name='Камила' 'Абдулкадеровна' 'Забила', group=121, date_of_birth=datetime.date(2005, 7, 2), inn=525677889930, gender='Ж'),
#  Student(id=22, name='Валентин' 'Гавриилович' 'Амуров', group=121, date_of_birth=datetime.date(2005, 4, 9), inn=525677889931, gender='М'),
#  Student(id=23, name='Хасан' 'Саидович' 'Аскеров', group=122, date_of_birth=datetime.date(2005, 1, 22), inn=525677889932, gender='М'),
#  Student(id=24, name='Ашот' 'Раисович' 'Нетот', group=122, date_of_birth=datetime.date(2005, 11, 11), inn=525677889933, gender='М'),
#  Student(id=25, name='Даша' 'Сергеевна' 'Неваляшкина', group=122, date_of_birth=datetime.date(2006, 12, 12), inn=525677889934, gender='Ж'),
#  Student(id=26, name='Элла' 'Назимовна' 'Накипелло', group=122, date_of_birth=datetime.date(2005, 9, 9), inn=525677889935, gender='Ж'),
#  Student(id=27, name='Каштан' 'Рамбутанович' 'Баклажан', group=122, date_of_birth=datetime.date(2005, 6, 26), inn=525677889936, gender='М'),
#  Student(id=28, name='Джон' '' 'Смит', group=123, date_of_birth=datetime.date(2005, 2, 23), inn=525677889937, gender='М'),
#  Student(id=29, name='Генрих' 'Азимутович' 'Штойц', group=123, date_of_birth=datetime.date(2005, 8, 6), inn=525677889938, gender='М'),
#  Student(id=30, name='Арам' 'Арамович' 'Бабаян', group=123, date_of_birth=datetime.date(2005, 5, 1), inn=525677889939, gender='М'),
#  Student(id=31, name='Ксюша' 'Ксилофоновна' 'Изплюша', group=123, date_of_birth=datetime.date(2005, 2, 11), inn=525677889940, gender='Ж'),
#  Student(id=32, name='Анна' 'Алексеевна' 'Одинцова', group=123, date_of_birth=datetime.date(2005, 10, 21), inn=525677889941, gender='Ж'),
#  Student(id=33, name='Алина' 'Александровна' 'Редькина', group=111, date_of_birth=datetime.date(2005, 5, 14), inn=52544444444, gender='Ж'),
#  Student(id=3, name='Петр' 'Петрович' 'Петров', group=111, date_of_birth=datetime.date(2005, 1, 3), inn=525677889911, gender='М'),
#  Student(id=38, name='Анна' 'Дмитриевна' 'Алексеева', group=111, date_of_birth=datetime.date(2006, 5, 1), inn=525677889999, gender=None),
#  Student(id=39, name='Сергей' 'Михайлович' 'Сергеев', group=111, date_of_birth=datetime.date(2006, 6, 2), inn=525677889922, gender=None),
#  Student(id=40, name='Ольга' 'Станиславовна' 'Ольгина', group=111, date_of_birth=datetime.date(2006, 7, 3), inn=525677889992, gender=None),
#  Student(id=41, name='Дмитрий' 'Алексеевич' 'Дмитриев', group=111, date_of_birth=datetime.date(2006, 8, 4), inn=525677889993, gender=None),
#  Student(id=42, name='Екатерина' 'Сергеевна' 'Петрова', group=111, date_of_birth=datetime.date(2006, 9, 1), inn=525677889988, gender=None)]

# %%
subq = select(Subject).where(Subject.subject.like("%тика")).subquery()
query = select(subq)
session.execute(query).all()
# Out:
# [(1, 'Математика'),
#  (2, 'Информатика'),
#  (3, 'Дискретная математика'),
#  (6, 'Высшая математика')]

# %%
subq = select(Subject).where(Subject.subject.notlike("%тика")).cte()
query = select(subq)
session.execute(query).all()
# Out:
# [(4, 'С++'), (5, 'Python')]

# %%
subq = select(Subject).where(~Subject.subject.notlike("%тика")).cte()
query = select(subq)
res = session.execute(query).all()
res
# Out:
# [(1, 'Математика'),
#  (2, 'Информатика'),
#  (3, 'Дискретная математика'),
#  (6, 'Высшая математика')]

# %%
import pandas as pd
r = pd.DataFrame(res)
r
# Out:
#    id                subject
# 0   1             Математика
# 1   2            Информатика
# 2   3  Дискретная математика
# 3   6      Высшая математика

# %%
stmt = select(Student.id).where(Student.groups_id == 1).join(Student.marks, isouter=True).where(Marks.mark == None)
res = session.execute(stmt).all()

# %%
import random
from sqlalchemy import insert
session = Session(engine)
for r in res:
    k = r[0]
    i = random.randrange(2,6)
    j = random.randrange(1,7)
    session.execute(
        insert(Marks),
        [
            {"student_id": k, "subject_id": j, "mark": i},
        ],
    )

session.commit()
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# UniqueViolation: ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "marks_student_id_uniq"
# DETAIL:  Ключ "(student_id)=(2)" уже существует.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[105], line 8
#       6     i = random.randrange(2,6)
#       7     j = random.randrange(1,7)
# ----> 8     session.execute(
#       9         insert(Marks),
#      10         [
#      11             {"student_id": k, "subject_id": j, "mark": i},
#      12         ],
#      13     )
#      15 session.commit()
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:2351, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2290 def execute(
#    2291     self,
#    2292     statement: Executable,
#    (...)
#    2298     _add_event: Optional[Any] = None,
#    2299 ) -> Result[Any]:
#    2300     r"""Execute a SQL expression construct.
#    2301
#    2302     Returns a :class:`_engine.Result` object representing
#    (...)
#    2349
#    2350     """
# -> 2351     return self._execute_internal(
#    2352         statement,
#    2353         params,
#    2354         execution_options=execution_options,
#    2355         bind_arguments=bind_arguments,
#    2356         _parent_execute_state=_parent_execute_state,
#    2357         _add_event=_add_event,
#    2358     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\session.py:2236, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2231     return conn.scalar(
#    2232         statement, params or {}, execution_options=execution_options
#    2233     )
#    2235 if compile_state_cls:
# -> 2236     result: Result[Any] = compile_state_cls.orm_execute_statement(
#    2237         self,
#    2238         statement,
#    2239         params or {},
#    2240         execution_options,
#    2241         bind_arguments,
#    2242         conn,
#    2243     )
#    2244 else:
#    2245     result = conn.execute(
#    2246         statement, params or {}, execution_options=execution_options
#    2247     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\bulk_persistence.py:1269, in BulkORMInsert.orm_execute_statement(cls, session, statement, params, execution_options, bind_arguments, conn)
#    1267     assert mapper is not None
#    1268     assert session._transaction is not None
# -> 1269     result = _bulk_insert(
#    1270         mapper,
#    1271         cast(
#    1272             "Iterable[Dict[str, Any]]",
#    1273             [params] if isinstance(params, dict) else params,
#    1274         ),
#    1275         session._transaction,
#    1276         isstates=False,
#    1277         return_defaults=insert_options._return_defaults,
#    1278         render_nulls=insert_options._render_nulls,
#    1279         use_orm_insert_stmt=statement,
#    1280         execution_options=execution_options,
#    1281     )
#    1282 elif insert_options._dml_strategy == "orm":
#    1283     result = conn.execute(
#    1284         statement, params or {}, execution_options=execution_options
#    1285     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\bulk_persistence.py:200, in _bulk_insert(mapper, mappings, session_transaction, isstates, return_defaults, render_nulls, use_orm_insert_stmt, execution_options)
#     160 extra_bp_names = (
#     161     [
#     162         b.key
#    (...)
#     167     else ()
#     168 )
#     170 records = (
#     171     (
#     172         None,
#    (...)
#     197     )
#     198 )
# --> 200 result = persistence._emit_insert_statements(
#     201     base_mapper,
#     202     None,
#     203     super_mapper,
#     204     table,
#     205     records,
#     206     bookkeeping=bookkeeping,
#     207     use_orm_insert_stmt=use_orm_insert_stmt,
#     208     execution_options=execution_options,
#     209 )
#     210 if use_orm_insert_stmt is not None:
#     211     if not use_orm_insert_stmt._returning or return_result is None:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\orm\persistence.py:1048, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1045 records = list(records)
#    1046 multiparams = [rec[2] for rec in records]
# -> 1048 result = connection.execute(
#    1049     statement, multiparams, execution_options=execution_options
#    1050 )
#    1051 if bookkeeping:
#    1052     for (
#    1053         (
#    1054             state,
#    (...)
#    1063         last_inserted_params,
#    1064     ) in zip(records, result.context.compiled_parameters):
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2353, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2351 elif should_wrap:
#    2352     assert sqlalchemy_exception is not None
# -> 2353     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2354 else:
#    2355     assert exc_info[1] is not None
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)
#    1978         context.executemany,
#    1979     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# IntegrityError: (psycopg2.errors.UniqueViolation) ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "marks_student_id_uniq"
# DETAIL:  Ключ "(student_id)=(2)" уже существует.
#
# [SQL: INSERT INTO marks (mark, subject_id, student_id) VALUES (%(mark)s, %(subject_id)s, %(student_id)s) RETURNING marks.id]
# [parameters: {'mark': 2, 'subject_id': 1, 'student_id': Decimal('2')}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
stmt = select(Marks)
session.execute(stmt).all()
# Out:
# [(Mark(id=1, mark=Decimal('3'), subject=Python, student='Петр' 'Петрович' 'Петров',),
#  (Mark(id=2, mark=Decimal('5'), subject=Python, student='Иван' 'Иванович' 'Иванов',),
#  (Mark(id=3, mark=Decimal('4'), subject=Python, student='Никита' 'Олегович' 'Никитин',),
#  (Mark(id=4, mark=Decimal('4'), subject=Python, student='Марина' 'Ивановна' 'Маринина',),
#  (Mark(id=5, mark=Decimal('3'), subject=Python, student='Жанна' 'Алексеевна' 'Сергеева',),
#  (Mark(id=6, mark=Decimal('2'), subject=Математика, student='Кирилл' 'Кириллович' 'Сергеев',),
#  (Mark(id=7, mark=Decimal('5'), subject=Информатика, student='Федя' 'Потапович' 'Колбаскин',),
#  (Mark(id=8, mark=Decimal('5'), subject=Математика, student='Ольга' 'Петровна' 'Петрова',),
#  (Mark(id=9, mark=Decimal('4'), subject=Математика, student='Валя' 'Патрикеевна' 'Изенштейн',),
#  (Mark(id=10, mark=Decimal('3'), subject=Математика, student='Дмитрий' 'Осипович' 'Оз',),
#  (Mark(id=11, mark=Decimal('3'), subject=Информатика, student='Остап' 'Изяславович' 'Остапов',),
#  (Mark(id=12, mark=Decimal('4'), subject=Информатика, student='Гена' 'Герасимович' 'Офиногенов',),
#  (Mark(id=13, mark=Decimal('2'), subject=Информатика, student='Лена' 'Валерьевна' 'Копытова',),
#  (Mark(id=14, mark=Decimal('5'), subject=Информатика, student='Петр' 'Иванович' 'Обломов',),
#  (Mark(id=15, mark=Decimal('5'), subject=Информатика, student='Зина' 'Леопольдовна' 'Турбина',),
#  (Mark(id=16, mark=Decimal('4'), subject=Дискретная математика, student='Аскольд' 'Тигранович' 'Распашный',),
#  (Mark(id=17, mark=Decimal('3'), subject=Дискретная математика, student='Петр' 'Алексеевич' 'Первый',),
#  (Mark(id=18, mark=Decimal('2'), subject=Дискретная математика, student='Данила' 'Кириллович' 'Мазила',),
#  (Mark(id=19, mark=Decimal('4'), subject=Дискретная математика, student='Камила' 'Абдулкадеровна' 'Забила',),
#  (Mark(id=20, mark=Decimal('5'), subject=Дискретная математика, student='Валентин' 'Гавриилович' 'Амуров',),
#  (Mark(id=21, mark=Decimal('3'), subject=С++, student='Хасан' 'Саидович' 'Аскеров',),
#  (Mark(id=22, mark=Decimal('3'), subject=С++, student='Ашот' 'Раисович' 'Нетот',),
#  (Mark(id=23, mark=Decimal('5'), subject=С++, student='Даша' 'Сергеевна' 'Неваляшкина',),
#  (Mark(id=24, mark=Decimal('4'), subject=Высшая математика, student='Элла' 'Назимовна' 'Накипелло',),
#  (Mark(id=25, mark=Decimal('2'), subject=Высшая математика, student='Каштан' 'Рамбутанович' 'Баклажан',),
#  (Mark(id=26, mark=Decimal('5'), subject=Высшая математика, student='Джон' '' 'Смит',),
#  (Mark(id=27, mark=Decimal('4'), subject=Высшая математика, student='Генрих' 'Азимутович' 'Штойц',),
#  (Mark(id=28, mark=Decimal('3'), subject=Высшая математика, student='Арам' 'Арамович' 'Бабаян',),
#  (Mark(id=29, mark=Decimal('3'), subject=Высшая математика, student='Ксюша' 'Ксилофоновна' 'Изплюша',),
#  (Mark(id=30, mark=Decimal('4'), subject=Высшая математика, student='Анна' 'Алексеевна' 'Одинцова',),
#  (Mark(id=31, mark=Decimal('5'), subject=Python, student='Алина' 'Александровна' 'Редькина',),
#  (Mark(id=38, mark=Decimal('3'), subject=Дискретная математика, student='Сергей' 'Михайлович' 'Сергеев',),
#  (Mark(id=39, mark=Decimal('4'), subject=Дискретная математика, student='Ольга' 'Станиславовна' 'Ольгина',),
#  (Mark(id=40, mark=Decimal('3'), subject=Дискретная математика, student='Анна' 'Дмитриевна' 'Алексеева',),
#  (Mark(id=41, mark=Decimal('5'), subject=С++, student='Екатерина' 'Сергеевна' 'Петрова',),
#  (Mark(id=42, mark=Decimal('2'), subject=Информатика, student='Дмитрий' 'Алексеевич' 'Дмитриев',)]

# %%
from sqlalchemy import select, update
import random

session = Session(engine)

for r in res:
    k = r[0]  
    print(k)
    stmt = select(Marks.mark).where(Marks.student_id == k)
    result = session.execute(stmt).all()
    if result:
        current_mark = result[0]
        print(current_mark)
        if current_mark == 2:
            new_mark = random.randrange(3, 5) 
            session.execute(
                update(Marks)
                .where(Marks.id == k)
                .values(mark=new_mark)
            )
            print(f"Обновлена оценка студента {k} с 2 на {new_mark}")
    
session.commit()
# Out:
# 2

# %%
stmt = select(Marks)
session.execute(stmt).all()
# Out:
# [(Mark(id=1, mark=Decimal('3'), subject=Python, student='Петр' 'Петрович' 'Петров',),
#  (Mark(id=2, mark=Decimal('5'), subject=Python, student='Иван' 'Иванович' 'Иванов',),
#  (Mark(id=3, mark=Decimal('4'), subject=Python, student='Никита' 'Олегович' 'Никитин',),
#  (Mark(id=4, mark=Decimal('4'), subject=Python, student='Марина' 'Ивановна' 'Маринина',),
#  (Mark(id=5, mark=Decimal('3'), subject=Python, student='Жанна' 'Алексеевна' 'Сергеева',),
#  (Mark(id=6, mark=Decimal('2'), subject=Математика, student='Кирилл' 'Кириллович' 'Сергеев',),
#  (Mark(id=7, mark=Decimal('5'), subject=Информатика, student='Федя' 'Потапович' 'Колбаскин',),
#  (Mark(id=8, mark=Decimal('5'), subject=Математика, student='Ольга' 'Петровна' 'Петрова',),
#  (Mark(id=9, mark=Decimal('4'), subject=Математика, student='Валя' 'Патрикеевна' 'Изенштейн',),
#  (Mark(id=10, mark=Decimal('3'), subject=Математика, student='Дмитрий' 'Осипович' 'Оз',),
#  (Mark(id=11, mark=Decimal('3'), subject=Информатика, student='Остап' 'Изяславович' 'Остапов',),
#  (Mark(id=12, mark=Decimal('4'), subject=Информатика, student='Гена' 'Герасимович' 'Офиногенов',),
#  (Mark(id=13, mark=Decimal('2'), subject=Информатика, student='Лена' 'Валерьевна' 'Копытова',),
#  (Mark(id=14, mark=Decimal('5'), subject=Информатика, student='Петр' 'Иванович' 'Обломов',),
#  (Mark(id=15, mark=Decimal('5'), subject=Информатика, student='Зина' 'Леопольдовна' 'Турбина',),
#  (Mark(id=16, mark=Decimal('4'), subject=Дискретная математика, student='Аскольд' 'Тигранович' 'Распашный',),
#  (Mark(id=17, mark=Decimal('3'), subject=Дискретная математика, student='Петр' 'Алексеевич' 'Первый',),
#  (Mark(id=18, mark=Decimal('2'), subject=Дискретная математика, student='Данила' 'Кириллович' 'Мазила',),
#  (Mark(id=19, mark=Decimal('4'), subject=Дискретная математика, student='Камила' 'Абдулкадеровна' 'Забила',),
#  (Mark(id=20, mark=Decimal('5'), subject=Дискретная математика, student='Валентин' 'Гавриилович' 'Амуров',),
#  (Mark(id=21, mark=Decimal('3'), subject=С++, student='Хасан' 'Саидович' 'Аскеров',),
#  (Mark(id=22, mark=Decimal('3'), subject=С++, student='Ашот' 'Раисович' 'Нетот',),
#  (Mark(id=23, mark=Decimal('5'), subject=С++, student='Даша' 'Сергеевна' 'Неваляшкина',),
#  (Mark(id=24, mark=Decimal('4'), subject=Высшая математика, student='Элла' 'Назимовна' 'Накипелло',),
#  (Mark(id=25, mark=Decimal('2'), subject=Высшая математика, student='Каштан' 'Рамбутанович' 'Баклажан',),
#  (Mark(id=26, mark=Decimal('5'), subject=Высшая математика, student='Джон' '' 'Смит',),
#  (Mark(id=27, mark=Decimal('4'), subject=Высшая математика, student='Генрих' 'Азимутович' 'Штойц',),
#  (Mark(id=28, mark=Decimal('3'), subject=Высшая математика, student='Арам' 'Арамович' 'Бабаян',),
#  (Mark(id=29, mark=Decimal('3'), subject=Высшая математика, student='Ксюша' 'Ксилофоновна' 'Изплюша',),
#  (Mark(id=30, mark=Decimal('4'), subject=Высшая математика, student='Анна' 'Алексеевна' 'Одинцова',),
#  (Mark(id=31, mark=Decimal('5'), subject=Python, student='Алина' 'Александровна' 'Редькина',),
#  (Mark(id=38, mark=Decimal('3'), subject=Дискретная математика, student='Сергей' 'Михайлович' 'Сергеев',),
#  (Mark(id=39, mark=Decimal('4'), subject=Дискретная математика, student='Ольга' 'Станиславовна' 'Ольгина',),
#  (Mark(id=40, mark=Decimal('3'), subject=Дискретная математика, student='Анна' 'Дмитриевна' 'Алексеева',),
#  (Mark(id=41, mark=Decimal('5'), subject=С++, student='Екатерина' 'Сергеевна' 'Петрова',),
#  (Mark(id=42, mark=Decimal('2'), subject=Информатика, student='Дмитрий' 'Алексеевич' 'Дмитриев',)]

# %%
from sqlalchemy import delete
import random

session = Session(engine)

random_ids = random.sample(range(1, 31), 2)

for mark_id in random_ids:
    session.execute(
        delete(Marks)
        .where(Marks.id == mark_id)
    )
    print(f"Удаление оценки с ID {mark_id}")

session.commit()
# Out:
# Удаление оценки с ID 13
# Удаление оценки с ID 7
